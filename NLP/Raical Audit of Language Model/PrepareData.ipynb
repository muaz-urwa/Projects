# %%
import PyPDF2 

try:
    from urllib import urlretrieve as urlretrieve
except ImportError:
    from urllib.request import urlretrieve as urlretrieve    

import os

#import matplotlib as plt
import pylab as pl
import pandas as pd
import string

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('articles1.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  17283  House Republicans Fret About Winning Their Hea...
# 1           1  17284  Rift Between Officers and Residents as Killing...
# 2           2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3           3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4           4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content
# ...

# %%
set(data.publication)
# Out:
# {'Atlantic', 'Breitbart', 'Business Insider', 'CNN', 'New York Times'}

# %%
sum(data.title.apply(lambda x: ('crime' in x.lower()) | ('race' in x.lower()) ))
# Out:
# 706

# %%
selectedData = data[data.title.apply(lambda x: ('crime' in x.lower()) | ('race' in x.lower()) )]

# %%
len(selectedData)
# Out:
# 706

# %%
selectedData.to_csv('selectedData.csv')

# %%
crimeArticles = data[data.title.apply(lambda x: 'crime' in x.lower() )]

# %%
len(crimeArticles)
# Out:
# 215

# %%
crimeArticles.to_csv('crimeData.csv')

# %%
crimeArticles
# Out:
#        Unnamed: 0     id                                              title  \
# 101           101  17400  How to Predict Gentrification: Look for Fallin...
# 122           122  17423  Beating of Disabled Teenager Highlights a Crim...
# 679           679  18045  Family DNA Searches Seen as Crime-Solving Tool...
# 1354         1354  18808  Hate Crime Is Feared as 2 Indian Engineers Are...
# 1673         1673  19157  Justin Bieber Impersonator Is Charged With Chi...
# 1877         1877  19384  7 Congo Army Officers Charged With War Crimes ...
# 2179         2179  19718  Liked ‘Serial’? Here’s Why the True-Crime Podc...
# 2325         2325  19878  Trump, Citing No Evidence, Suggests Susan Rice...
# 2560         2560  20141  On Crime Bill and the Clintons, Young Blacks C...
# 2997         2997  20609  In Russian Doping Scandal, Time for a Punishme...
# 4320         4320  22080  Marijuana Arrests Outnumber Those for Violent ...
# ...

# %%
crimeArticles.content.values[214]
# Out:
# '’  ’ ’   A federal jury has convicted Dylann Roof in the racially   motivated slayings of nine black church members in South   Carolina. ’ ’ They convicted the    white man of    obstruction of religion and weapons charges. ’ ’   The same jury will reconvene next month to decide whether Roof   should get the death penalty or be sentenced to life in prison. ’ ’  ’ ’  ’ ’’ ’  ’ ’   Roof just stared ahead as the verdict was   read, much as he has throughout the trial. ’ ’    ’ ’   He confessed to   officials shortly after he was   arrested that he ultimately decided he ”had to go through with   his mission.” ’ ’  ’ ”   Jurors heard from witnesses who testified Roof made multiple   trips to Charleston in the months before the June 2015 attack at   Emanuel AME Church. They also heard from two survivors. Roof’s   attorneys called no witnesses. ” ’   Prosecutors said in their closing arguments Roof was filled with   hate and has already confessed to the FBI to his role in the   shootings. 
# ...

# %%
crimeArticles.publication.value_counts()
# Out:
# Breitbart           146
# CNN                  37
# New York Times       19
# Business Insider     13
# Name: publication, dtype: int64
