# %%
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
import string
import json
import numpy as np
import pandas as pd
import re
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import random

# %%
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout
from keras import regularizers
from keras.models import model_from_json
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
def save_list(lines, filename):
	data = '\n'.join(lines)
	file = open(filename, 'w')
	file.write(data)
	file.close()

# %% [markdown]
# ### load spacy model

# %%
import spacy
# Load the large English NLP model
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ## NER based sentence Filter Methods

# %%
def containsEntity(entities, sentence):
    for e in entities:
        if e.start >= sentence.start and e.end <= sentence.end:
            return True
    return False

# %%
def excludeReference(text):
    tokens = text.split()
    l = len(tokens)
    if 'REFERENCES' in tokens:
        ind = l-1-tokens[::-1].index('REFERENCES')
    elif 'References' in tokens:
        ind = l-1-tokens[::-1].index('References')
    else:
        ind = l
    return ' '.join(tokens[:ind])

# %% [markdown]
# ### Data Preprocessing Methods

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
 
ps = PorterStemmer()

# %%
## Abbreviation Disambiguation Module

## load abbreviations
file = 'abbreviations.json'
abbtext = load_doc(file)
abbreviations = json.loads(abbtext)

def findAbbreviation(sentence):
    regex = r"\b[A-Z][A-Z]+\b"
    abbreviations = re.findall(regex, sentence)
    return abbreviations

def expandAbbreviation(sentence, abbdict):
    abbs = findAbbreviation(sentence)
    for a in abbs:
        if a in abbdict:
            sentence = sentence.replace(a,abbdict[a][0])
    return sentence

# %%
def specialMapping(word):
    if word == 'studi':
        return 'survey'
    else:
        return word

# %%
# turn a doc into clean tokens
def clean_doc(doc):
    # abbreviation disambiguation
    doc = expandAbbreviation(doc, abbreviations)
    # split into tokens by white space
    tokens = doc.split()
    # Exclude text below references
    #tokens = excludeReference(tokens)
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # make lower case
    tokens = [word.lower() for word in tokens]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # stemming
    tokens = [ps.stem(word) for word in tokens]
    #specialMapping
    tokens = [specialMapping(word) for word in tokens]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens

# %%
# load doc, clean and return line of tokens
def doc_to_line(sentence, vocab):
	# clean doc
	tokens = clean_doc(sentence)
	# filter by vocab
	tokens = [w for w in tokens if w in vocab]
	return ' '.join(tokens)

# %%
# load all docs in a directory
def process_docs(sentences, vocab):
    lines = list()
    # walk through all files in the folder
    for sentence in sentences:
        # load and clean the doc
        line = doc_to_line(sentence, vocab)
        # add to list
        lines.append(line)
    return lines

# %% [markdown]
# ### Load Keras Tokenizer

# %%
def load_Keras_Tokenizer_CNN(pickleFilePath):
    with open(pickleFilePath, 'rb') as handle:
       tokenizer = pickle.load(handle)
    return tokenizer

# %% [markdown]
# ### Load CNN and weights

# %%
def load_CNN_Sentece_Classifier(modelFile, weightsFile):
    # load json and create model
    json_file = open(modelFile, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)   
    # load weights into new model
    model.load_weights("CNNmodel.h5")
    # compile network
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print("Loaded model from disk")
    return model

# %% [markdown]
# ### Load Dataset Vocabulary for Ngram

# %%
def loadVocab(vocabFile):
    vocab = load_doc(vocabFile)
    vocab = vocab.split()
    vocab = set(vocab)
    return vocab

# %% [markdown]
# ### Load Dataset Titles and IDs

# %%
def loadDataSetTitlesAndIds(datasetJsonFile):
    text = load_doc(datasetJsonFile)
    loaded_json_all = json.loads(text)
              
    dataSetIds = [ dataset['data_set_id'] for dataset in loaded_json_all ]
    dataSetTitles = [ dataset['title'] for dataset in loaded_json_all ]
    dataSetDate = [ dataset['date'] for dataset in loaded_json_all ]
    datasetyears = [int(d[:4]) if d != 'None' else 0 for d in dataSetDate]
    return datasetyears,dataSetIds,dataSetTitles

# %% [markdown]
# ### Labelling helper function

# %%
def getLabelLength(labels):
    return [len(l) for l in labels]

# %% [markdown]
# ### Group Search Helper Methods

# %%
def treatDates(tokens):
    rawDates = []
    for token in tokens:
        if len(token) == 6: #200108
            if re.match(r'([1-2][09][0-9]{4})', token):
                start = int(token[0:4])
                end = int(token[:2]+token[4:6])
                if (end>start):
                    years = list( range(start,end+1) )
                    years = [str(y) for y in years]
                    rawDates.append(token)
                    tokens += years
        if len(token) == 8: #20012008
            if re.match(r'([0-2][09][0-9]{2}[0-2][09][0-9]{2})', token):
                start = int(token[0:4])
                end = int(token[4:8])
                if (end>start):
                    years = list( range(start,end+1) )
                    years = [str(y) for y in years]
                    rawDates.append(token)
                    tokens += years
    tokens = [t for t in tokens if t not in rawDates]
    return tokens

# %%
#Fix2
def expandDatesWithTo(text):
    matches = re.findall(r'([1-2][09][0-9]{2} to [1-2][09][0-9]{2})', text)
    for m in matches:
        start = int(m[0:4])
        end = int(m[8:12])
        if (end>start):
            years = list( range(start,end+1) )
            years = [str(y) for y in years]
            text += " " + ' '.join(years)
    return text

# %%
def clean_mention(doc):
    # abbreviation disambiguation
    doc = expandAbbreviation(doc, abbreviations)
    
    #expand dates like 2000 to 2002 into 2002 2001 2002 #Fix2
    doc = expandDatesWithTo(doc)
    
    # split into tokens by white space
    tokens = doc.split()

    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    
    # make lower case
    tokens = [word.lower() for word in tokens]
    
    # remove remaining tokens that are not alphabetic
    #tokens = [word for word in tokens if not word.isalpha()]
    tokenTemp = tokens.copy()
    # treat dates
    tokens = treatDates(tokens)
    
    # filter out stop words
    #stop_words = set(stopwords.words('english'))
    #tokens = [w for w in tokens if not w in stop_words]
    
    # stemming
    tokens = [ps.stem(word) for word in tokens]
    
    #specialMapping
    tokens = [specialMapping(word) for word in tokens]
    

    return " ".join(tokens)

# %%
def min_max_scale(X):
    mini = np.min(X)
    #mini = 0
    maxi = np.max(X)
    if maxi == 0:
        return X
    return (X - mini) / (maxi - mini)

# %%
def min_max_2D(X):
    rowList = []
    for i in range(X.shape[0]):
        rowList.append(min_max_scale(X[i]))
    return np.array(rowList)

# %%
def zscore_scale(X):
    #mini = np.min(X)
    mean = np.mean(X)
    std = np.std(X)
    if std == 0:
        return np.zeros(len(X))
    return (X - mean) / (std)

# %%
def zscore_scale_2D(X):
    rowList = []
    for i in range(X.shape[0]):
        rowList.append(min_max_scale(X[i]))
    return np.array(rowList)

# %%
def getMaxyear(dateEntities):
    maxdate = 1900
    for de in dateEntities:
        dates = re.findall(r'([1-2][09][0-9]{2})', de.text)
        if len(dates) == 0:
            continue
        dates = [int(d) for d in dates]
        date = np.max(dates)
        if date > maxdate:
            maxdate = date
    return maxdate

# %% [markdown]
# ## Debuf Functions

# %%
def print_Hits(sentence,score):
    s,d = zip(*sorted(zip(score, sentence)))
    for i in range(len(s)):
        print(s[i])
        print(d[i])
        print()

# %%
def getTrueLabels(samplePublications):
    sampleTextFiles = [p['text_file_name'] for p in samplePublications]
    file = 'publications.json'
    directory = '/home/urwa/Documents/Coleridge/ProjectFiles/train_test/train_test/'
    pub_json = pd.read_json(directory+file)

    pub_json.head()

    pub_json = pub_json[['text_file_name','publication_id']]
    pub_json = pub_json[pub_json.text_file_name.apply(lambda x: x in sampleTextFiles)]
    pub_json.head()

    file = 'data_set_citations.json'
    directory = '/home/urwa/Documents/Coleridge/ProjectFiles/train_test/train_test/'
    cit = pd.read_json(directory+file)

    cit = cit[['data_set_id', 'publication_id']]
    cit.head()

    pub_json = pub_json.merge(cit, left_on=['publication_id'], right_on=['publication_id'], how='left')
    pub_json.head()

    len(pub_json)

    pub_json = pub_json[['text_file_name','data_set_id']]
    pub_json.columns =  ['file','data_set_id']
    pub_json['file'] = pub_json.file.apply(lambda x : x.split('.')[0])
    pub_json['data_set_id'] = pub_json['data_set_id'].astype(int)
    pub_json['file'] = pub_json['file'].astype(int)
    return pub_json

# %%
def evaluationMetrics(trueLabels,resultsDF):
    truePair = set(zip(trueLabels.file.values, trueLabels.data_set_id.values))
    predPair = set(zip(resultsDF.publication_id.values, resultsDF.data_set_id.values))
    print(len(set(trueLabels.data_set_id.values).intersection(set(resultsDF.data_set_id.values))))
    print('Intersection : ',len(truePair.intersection(predPair)))
    print(truePair)
    print(predPair)
    recall = len(truePair.intersection(predPair)) / len(truePair)
    precision = len(truePair.intersection(predPair)) / len(predPair)
    if precision == 0 or recall == 0:
        return 0,0,0
    fscore = 2 * (precision * recall) / (precision + recall)
    return recall,precision,fscore

# %% [markdown]
# ### Directories and Files Contstants

# %%
TEXT_DIRECTORY = '/home/urwa/Documents/Coleridge/ProjectFiles/train_test/train_test/files/text/'
CNN_TOKENIZER_File = 'CNNtokenizer.pickle'
CNN_MODEL_FILE = 'CNNmodel.json'
CNN_MODEL_WEIGHTS_FILE = "CNNmodel.h5"
DATASET_VOCAB_FILE = 'dataset_vocab_production.txt'
CNN_VOCAB_FILE = 'bmvocab.txt'
DATSETS_JSON_FILE = '/home/urwa/Documents/Coleridge/ProjectFiles/train_test/train_test/data_sets.json'
PROCESSED_DATASET_LINES = 'datasets_lines_production.txt'
PUBLICATIONS_JSON_FILE = '/home/urwa/Documents/Coleridge/ProjectFiles/train_test/train_test/publications.json'
OUTPUT_DIRECTORY = '/home/urwa/Documents/Coleridge/notebooks/SubsetAnalysis/Notes/'

# %%
# MAX_CNN_SEQ_LENGTH = 66
# HIT_THRESHHOLD = 0.9
# SIM_THRESHHOLD = 0.3
# GROUP_SIM_THRESHHOLD = 0.5

# %%
def save_citations(DF):
    data = DF.to_dict('records')
    with open(OUTPUT_DIRECTORY+'data_set_citations.json', 'w') as fp:
        json.dump(data, fp)

# %%
def save_mentions(DF):
    data = DF.to_dict('records')
    with open(OUTPUT_DIRECTORY+'data_set_mentions.json', 'w') as fp:
        json.dump(data, fp)

# %% [markdown]
# ## Get the filenames

# %%
def getFileNames():
    txtFiles = os.listdir(TEXT_DIRECTORY)
    txtFiles = [t for t in txtFiles if not (t.startswith(".") and t.endswith('.txt')) ]
    labelledFiles = load_doc('labelledTextFiles.txt').split('\n')
    unlabbellledtxtFiles = [t for t in txtFiles if t not in labelledFiles]
    print("FileCount:",len(txtFiles))
    return labelledFiles
#Fix

# %%
## Returns ORG entities and sentences
def parseSpacy(text):
    text = excludeReference(text)
    spacydoc = nlp(text)
    sentences = list(spacydoc.sents)
    entities = [e for e in spacydoc.ents if e.label_ == 'ORG']
    dates = [e for e in spacydoc.ents if e.label_ == 'DATE']
    print("Sentences: ",len(sentences))
    return dates,sentences,entities

# %%
def filterSentencesByNer(sentences,entities):
    filteredSentences = [s.text for s in sentences if containsEntity(entities, s)]
    filteredSentences = list(set(filteredSentences))
    print("Filtered Sentences: ",len(filteredSentences))
    return filteredSentences

# %%
def removeSpecialCharacters(sentences):
    sentences = [s.replace('\n',' ') for s in sentences]
    sentences = [s.replace('\xad', '') for s in sentences]
    return sentences

# %%
def getMentionSentencesDF(filteredSentences, y_hat, y_prob, threshHold):
    DF = pd.DataFrame({'sentence':filteredSentences,'Pscore': y_prob})
    DF = DF[DF.Pscore > threshHold]
    print('Dataset Mentions: ',len(DF))
    return DF

# %%
def getDataSetProcessedLines():
    # each field as a sentence
    docs = load_doc(PROCESSED_DATASET_LINES).split('\n')
    return docs

# %%
def getDatasetNgramVectorizer(docs):
    # create the tokenizer
    vectorizer = TfidfVectorizer(ngram_range=(2, 4))
    # fit the tokenizer on the documents
    tfidVec = vectorizer.fit(docs)
    return tfidVec

# %%
def getSimilarityMatrix_sent_datasets(hitSents,vectorizerDataset,dataset_Ngram):   
    # prepare negative reviews
    sents = process_docs(hitSents, dataset_vocab)    
    # encode training data set
    sents_Ngram = vectorizerDataset.transform(sents)
    #print('Sentence TFID shape: ',sents_Ngram.shape)
    Cos_Sim = cosine_similarity(sents_Ngram, dataset_Ngram, dense_output=True)
    print('Cos Sim shape: ',Cos_Sim.shape)
    return Cos_Sim

# %%
def getDatasetCandidateMatchesDF(df,Cos_Sim,dataSetIds,dataSetTitles,datasetYears, sim_threshHold,pubId,pubYear):  
    #Cos_Sim = min_max_2D(Cos_Sim)
    DataLabel = []
    DataTitle = []
    sim_score = []
    for i in range(Cos_Sim.shape[0]):
        did = []
        dtit = []
        sscr = []
        for j in range(len(Cos_Sim[0])):
            if(Cos_Sim[i][j] > sim_threshHold and datasetYears[j] <= pubYear ):
                did.append(dataSetIds[j])
                dtit.append(dataSetTitles[j])
                sscr.append(Cos_Sim[i][j])
        DataLabel.append(did)
        DataTitle.append(dtit)
        sim_score.append(sscr)
    
    df['matches'] = getLabelLength(DataLabel)
    df['datasetIds'] = DataLabel
    df['data_sim_scores'] = sim_score
    df['datasetTitles'] = DataTitle
    df['pubID'] = pubId
    return df

# %%
def mergeSimilarDatasets(DF):
    datasetgroups = []
    for i in range(len(DF.datasetTitles)):
        tit = DF.datasetTitles.values[i]
        if not tit:
            continue
        found = False
        for j in range(len(datasetgroups)):
            if len(set(datasetgroups[j]).intersection(set(tit))) > 0:
                datasetgroups[j] = list(set(datasetgroups[j]).union(set(tit)))
                found = True
                break
        if not found:
            datasetgroups.append(tit)
    print('Numer of Groups: ',len(datasetgroups))
    print('Group Sizes',[len(d) for d in datasetgroups])
    return datasetgroups

# %%
def getGroupHitsSimMatrix(currentgroup,groupHits):
    # each field as a sentence
    docs = [ clean_mention(c) for c in currentgroup ]
    # create the tokenizer
    vectorizer = TfidfVectorizer(ngram_range=(1, 3))
    # fit the tokenizer on the documents
    bow = vectorizer.fit(docs)
    # encode training data set
    sentence_bow = bow.transform(docs)
    #print(sentence_bow.shape)
    #each field as a sentence
    docs = [" ".join([ clean_mention(c) for c in groupHits])] 

    # encode training data set
    doc_bow = bow.transform(docs)
    #print(doc_bow.shape)
    
    data_sim = cosine_similarity(doc_bow, sentence_bow, dense_output=True)
    
    group_sim_scores = min_max_scale(data_sim.reshape(data_sim.shape[1]))
    return group_sim_scores

# %%
def citationScoring(mentions,score):
    scrs = []
    for i in range(len(score)):
        if len(mentions[i]) == 1:
            scrs.append(0.6 * score[i])
        if len(mentions[i]) == 2:
            scrs.append(0.7 * score[i])
        if len(mentions[i]) == 3:
            scrs.append(0.8 * score[i])
        if len(mentions[i]) >= 4:
            scrs.append(1 * score[i])       
    return scrs

# %%
def generateResults(datasetgroups,dataset_name_to_Id,DF,pubId,GROUP_SIM_THRESHHOLD):
    
    finalLabelList = []
    for i in range(len(datasetgroups)):
        currentgroup = datasetgroups[i]
        
        groupHits = [s for s,t in zip(DF.sentence,DF.datasetTitles) if len(set(t).intersection(set(currentgroup))) > 0 ]  #  
        
        if(len(currentgroup)<2):
            row = {}
            row['publication_id'] = pubId
            row['data_set_id'] = dataset_name_to_Id[currentgroup[0]]
            row['score'] = 1
            row['mention_list'] = groupHits
            finalLabelList.append(row)
            continue
        
        group_sim_scores = getGroupHitsSimMatrix(currentgroup,groupHits)
        print('Group ',i,' : ',group_sim_scores.shape)
        
        #print_Hits(currentgroup, group_sim_scores)
        hit_tit_scr = [ (tit,scr) for tit,scr in zip(currentgroup,group_sim_scores) if scr > GROUP_SIM_THRESHHOLD ]
        
        filterLen = min(len(groupHits) * 2,len(hit_tit_scr))
        hit_tit_scr.sort(key=lambda x: -x[1])
        hit_tit_scr = hit_tit_scr[:filterLen]
    
        for hid in hit_tit_scr:
            row = {}
            row['publication_id'] = pubId
            row['data_set_id'] = dataset_name_to_Id[hid[0]]
            row['score'] = hid[1]
            row['mention_list'] = groupHits
            finalLabelList.append(row)
            
    finalLabelDF = pd.DataFrame(finalLabelList)
    if len(finalLabelDF) > 0:
        finalLabelDF['score'] = citationScoring(finalLabelDF.mention_list.values, finalLabelDF.score.values)
    return finalLabelDF

# %%
a = [('one',1),('seven',7),('three',3),('nine',9)]
a.sort(key=lambda x: -x[1])
a
# Out:
# [('nine', 9), ('seven', 7), ('three', 3), ('one', 1)]

# %%
def mentionScoring(prob,matches,avgSimScore):
    if matches > 4:
        return 1
    if matches == 0:
        return 0.7 * prob
    if avgSimScore >= 0.5:
        return 0.9 * prob
    if avgSimScore < 0.5:
        return 0.8 * prob

# %%
def getMentionsResults(DF):
    DF['AvgSimScore'] = DF.data_sim_scores.apply(lambda x: np.mean(x) if len(x)>0 else 0)
    calScore = np.vectorize(mentionScoring)
    score = calScore(DF.Pscore.values, DF.matches.values, DF.AvgSimScore.values)
    DF['score'] = score
    DF = DF[['pubID','sentence','score']]
    DF.columns = ['publication_id', 'mention', 'score']
    return DF

# %%
def runPipeLine(publications, max_seq_len, hit_th , sim_th, group_sim_th):
    citationsDF = None
    mentionsDF = None
    for pub in publications:
        file = pub['text_file_name']
        pubId = pub['publication_id']
        txt = load_doc(TEXT_DIRECTORY+file)
        dates,sentences,entities = parseSpacy(txt)
        filteredSentences = filterSentencesByNer(sentences,entities)
        filteredSentences = removeSpecialCharacters(filteredSentences)
        
        pubYear = getMaxyear(dates)
        
        processed_lines = process_docs(filteredSentences, cnnVocab)
        encoded_docs = cnnTokenizer.texts_to_sequences(processed_lines)
        processed_sequences = pad_sequences(encoded_docs, maxlen=max_seq_len, padding='post')
        y_prob = model.predict(processed_sequences).reshape(len(processed_lines))
        y_hat = model.predict_classes(processed_sequences).reshape(len(processed_lines))

        classifierResultDF = getMentionSentencesDF(filteredSentences, y_hat, y_prob, hit_th)

        if len(classifierResultDF) < 1:
            print("No mentions for file : ",file)
            continue
    
        cosineSim_sent_dataset = getSimilarityMatrix_sent_datasets(classifierResultDF.sentence.values, \
                                                          vectorizerDataset,dataset_Ngram)

        candidateMatchesDF = getDatasetCandidateMatchesDF(classifierResultDF,cosineSim_sent_dataset, \
                                                          dataSetIds,dataSetTitles,dataSetYears, \
                                                          sim_th,pubId,pubYear)
        
        datasetGroupsTitles = mergeSimilarDatasets(candidateMatchesDF)

        resDf = generateResults(datasetGroupsTitles,dataset_name_to_Id,candidateMatchesDF,pubId, \
                                group_sim_th)
        
        
        mentionsdf = getMentionsResults(candidateMatchesDF)
        
        if mentionsDF is None:
            mentionsDF = mentionsdf
        else:
            mentionsDF = mentionsDF.append(mentionsdf)
    
        if citationsDF is None:
            citationsDF = resDf
        else:
            if len(resDf) < 1:
                print("No dataset matched mentions for file : ",file)
            else:
                citationsDF = citationsDF.append(resDf)
        print()   
    return citationsDF,mentionsDF

# %%
def evaluatePipeline(samplePublications,Th,Ts,Tgs):
    resultsDF,_ = runPipeLine(samplePublications,max_seq_len = 66, hit_th = Th, \
                            sim_th = Ts,group_sim_th = Tgs)
    print('ResultDf Length : ',len(resultsDF))
    if resultsDF is None:
        return {'Th':Th, 'Ts':Ts ,'Tgs':Tgs, 'recall': 0, 'precision': 0, 'fscore': 0}
    trueLabels = getTrueLabels(samplePublications)
    print('TrueLabel Length : ',len(trueLabels))
    recall,precision,fscore = evaluationMetrics(trueLabels,resultsDF)
    return {'Th':Th, 'Ts':Ts ,'Tgs':Tgs, 'recall': recall, 'precision': precision, 'fscore': fscore}

# %%
def get_publications():
    pubText = load_doc(PUBLICATIONS_JSON_FILE)
    pubJson = json.loads(pubText)
    return pubJson

# %%
#textFiles = getFileNames()
publications = get_publications()
publications = [p for p in publications if os.path.isfile(TEXT_DIRECTORY+p['text_file_name'])]
dataSetYears,dataSetIds,dataSetTitles = loadDataSetTitlesAndIds(DATSETS_JSON_FILE)
dataset_name_to_Id = dict(zip(dataSetTitles, dataSetIds))

cnnVocab = loadVocab(CNN_VOCAB_FILE)
cnnTokenizer = load_Keras_Tokenizer_CNN(CNN_TOKENIZER_File)
model = load_CNN_Sentece_Classifier(CNN_MODEL_FILE, CNN_MODEL_WEIGHTS_FILE)

dataset_vocab = loadVocab(DATASET_VOCAB_FILE)
datasetlines = getDataSetProcessedLines()
vectorizerDataset = getDatasetNgramVectorizer(datasetlines)
dataset_Ngram = vectorizerDataset.transform(datasetlines)
print('DataSet TFID shape: ',dataset_Ngram.shape)
# Out:
# Loaded model from disk
# DataSet TFID shape:  (10348, 66233)

# %%
os.path.isfile(TEXT_DIRECTORY+publications[0]['text_file_name'])
# Out:
# False

# %%
labelledFiles = load_doc('labelledTextFiles.txt').split('\n')
labelledPublications = [p for p in publications if p['text_file_name'] in labelledFiles]
sampleSize = 500
sampleIndex = np.random.randint(0,len(labelledPublications),sampleSize)
samplePublications = [t for i,t in enumerate(labelledPublications) if i in sampleIndex]
len(samplePublications)
# Out:
# 459

# %%
resultsDF,matchDF = runPipeLine(samplePublications[:3],max_seq_len = 66, hit_th = 0.8, \
                            sim_th = 0.2,group_sim_th = 0.8)
# Out:
# Sentences:  392
# Filtered Sentences:  56
# 56/56 [==============================] - 0s 140us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  2
# Group Sizes [1, 2]
# Group  1  :  (2,)
# /home/urwa/miniconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys
# Sentences:  770
# Filtered Sentences:  118
# 118/118 [==============================] - 0s 108us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  3
# Group Sizes [4, 3, 1]
# Group  0  :  (4,)
# Group  1  :  (3,)
#
# Sentences:  792
# Filtered Sentences:  195
# 195/195 [==============================] - 0s 119us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  2
# Group Sizes [1, 18]
# Group  1  :  (18,)

# %%
save_citations(resultsDF)
save_mentions(matchDF)

# %% [markdown]
# ## Research Fields

# %%
SAGE_FIELDS_FILE = '/home/urwa/Documents/Coleridge/ProjectFiles/train_test/train_test/sage_research_fields.json'
SAGE_VOCAB_FILE =  'sage_fields_wiki_vocab.txt'  #'sage_fields_vocab.txt'
SAGE_FIELDS_LINES = 'wiki_fields_lines.txt' #'fields_lines.txt'
SAGE_WIKI_FIELDS = 'sage_fields_wiki.txt'

# %%
# turn a doc into clean tokens
def fields_clean_doc(doc):
    #
    doc = doc.replace('(general)','')
    
    # split into tokens by white space
    tokens = doc.split()
    
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    
    # make lower case
    tokens = [word.lower() for word in tokens]
    
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    
    # filter special words
    special_words = ['fieldaltlabel','fieldid','fieldlabel']
    tokens = [w for w in tokens if not w in special_words]
    
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens

# %%
# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
	# load the doc
	doc = load_doc(filename)
	# clean doc
	tokens = fields_clean_doc(doc)
	# filter by vocab
	tokens = [w for w in tokens if w in vocab]
	return ' '.join(tokens)

# %%
# load all docs in a directory
def fields_process_docs(publications, vocab):
    lines = list()
    for pub in publications:
        path = TEXT_DIRECTORY+pub['text_file_name']
        line = doc_to_line(path, vocab)
        lines.append(line)
    return lines

# %%
def getFieldsSimMatrix(field_lines,pub_lines):
    # create the tokenizer
    vectorizer = TfidfVectorizer(ngram_range=(1, 2))
    # fit the tokenizer on the documents
    fieldTokenizer = vectorizer.fit(field_lines)
    # encode training data set
    fieldsNgram = fieldTokenizer.transform(field_lines)
    #print(fieldsNgram.shape)
    # encode training data set
    pubNgram = fieldTokenizer.transform(pub_lines)
    #print(doc_bow.shape)
    data_sim = cosine_similarity(pubNgram,fieldsNgram,dense_output=True)
    #print(data_sim.shape)
    #group_sim_scores = min_max_scale(data_sim.reshape(data_sim.shape[1]))
    return data_sim

# %%
def getSageFieldsWiki(publications):
    fields = load_doc(SAGE_WIKI_FIELDS).split('\n')

    sageVocab = load_doc(SAGE_VOCAB_FILE).split()
    processed_lines = fields_process_docs(publications, sageVocab)
    field_lines = load_doc(SAGE_FIELDS_LINES).split('\n')
    sim =getFieldsSimMatrix(field_lines, processed_lines)
    fieldLabels = [fields[np.argmax(c_s)] for c_s in sim]

    #print(fieldLabels)
    pubIds = [p['publication_id'] for p in publications]
    score = np.ones(len(publications))
    return pd.DataFrame({'publication_id': pubIds, 'research_field': fieldLabels, 'score': score}).to_dict('records')

# %%
def getSageFields(publications):
    text = load_doc(SAGE_FIELDS_FILE)
    sage_fields_json = json.loads(text)
    fields = list(sage_fields_json.keys())

    sageVocab = load_doc(SAGE_VOCAB_FILE).split()
    processed_lines = fields_process_docs(publications, sageVocab)
    field_lines = load_doc(SAGE_FIELDS_LINES).split('\n')
    sim =getFieldsSimMatrix(field_lines, processed_lines)
    fieldLabels = [fields[np.argmax(c_s)] for c_s in sim]

    SubFieldLabels = []
    for i in range(len(processed_lines)):
        subFieldJson = sage_fields_json[fieldLabels[i]]
        subFields = list(subFieldJson.keys())
        subLines = []
        for sf in subFields:
            subLines.append(' '.join(clean_doc(str(subFieldJson[sf]))))
        subSim =getFieldsSimMatrix(subLines, [processed_lines[i]])
        label = subFields[np.argmax(subSim[0])]
        SubFieldLabels.append(label)

    finalLabels = [f+" : "+s for f,s in zip(fieldLabels,SubFieldLabels)]
    #print(finalLabels)
    pubIds = [p['publication_id'] for p in publications]
    score = np.ones(len(publications))
    return pd.DataFrame({'publication_id': pubIds, 'research_field': finalLabels, 'score': score}).to_dict('records')

# %%
sageFieldsJson = getSageFieldsWiki(samplePublications)
with open(OUTPUT_DIRECTORY+'research_fields.json', 'w') as fp:
        json.dump(sageFieldsJson, fp)

# %% [markdown]
# ## Research Methods

# %%
SAGE_METHODS_VOCAB = 'sage_methods_vocab.txt'

# %%
def getSageMethods(publications):
    sageMethodVocab = load_doc(SAGE_METHODS_VOCAB).split('\n')
    methodsList = []
    for pub in publications:
        txt = load_doc(TEXT_DIRECTORY + pub['text_file_name'])
        tok = txt.split()
        # remove punctuation from each token
        table = str.maketrans('', '', string.punctuation)
        tok = [w.translate(table) for w in tok]
        # remove remaining tokens that are not alphabetic
        tok = [word for word in tok if word.isalpha()]
        # remove the tokens not in vocab
        tok = [word for word in tok if word in sageMethodVocab]
        # count occurences
        counter = Counter()
        counter.update(tok)
        # dictionary to score by count
        scoreDict = {4:0.2, 5:0.4, 6:0.6, 7:0.8, 8:1}
        # methods and their counts
        meth = [k for k,c in counter.items() if c > 3]
        cnt = [c if c<=8 else 8 for k,c in counter.items() if c > 3]
        # computing score
        scr = [scoreDict[k] for k in cnt]
        # populating list of dictionary
        mList = []
        for i in range(len(meth)):
            row = {}
            row['publication_id'] = pub['publication_id']
            row['method'] = meth[i]
            row['score'] = scr[i]
            mList.append(row)
        methodsList += mList
    return methodsList

# %%
sageMethodsJson = getSageMethods(samplePublications)
with open(OUTPUT_DIRECTORY+'methods.json', 'w') as fp:
        json.dump(sageFieldsJson, fp)

# %% [markdown]
# ## Parameter Tuning

# %%
# %%time
import itertools

parameterResults = []
ThList = [0.8]
TsList = [0.1]
TgsList = [0.6]

parameterSpace = [ThList, TsList, TgsList]

for Th,Ts,Tgs in list(itertools.product(*parameterSpace)):
    par_res = evaluatePipeline(samplePublications,Th,Ts,Tgs)
    parameterResults.append(par_res)
# Out:
# Sentences:  392
# Filtered Sentences:  56
# 56/56 [==============================] - 0s 129us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  2
# Group Sizes [7, 2]
# Group  0  :  (7,)
# Group  1  :  (2,)
#
# Sentences:  770
# Filtered Sentences:  118
# 118/118 [==============================] - 0s 109us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  3
# Group Sizes [8, 3, 2]
# Group  0  :  (8,)
# Group  1  :  (3,)
# Group  2  :  (2,)
#
# Sentences:  792
# Filtered Sentences:  195
# 195/195 [==============================] - 0s 124us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  2
# Group Sizes [4, 1]
# Group  0  :  (4,)
#
# Sentences:  580
# Filtered Sentences:  55
# 55/55 [==============================] - 0s 140us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  2
# Group Sizes [1, 6]
# Group  1  :  (6,)
#
# Sentences:  194
# Filtered Sentences:  85
# 85/85 [==============================] - 0s 139us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [33]
# Group  0  :  (33,)
#
# Sentences:  345
# Filtered Sentences:  41
# 41/41 [==============================] - 0s 158us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  2
# Group Sizes [405, 3]
# Group  0  :  (405,)
# Group  1  :  (3,)
#
# Sentences:  200
# Filtered Sentences:  26
# 26/26 [==============================] - 0s 130us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  1
# Group Sizes [33]
# Group  0  :  (33,)
#
# Sentences:  315
# Filtered Sentences:  59
# 59/59 [==============================] - 0s 158us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  2
# Group Sizes [1, 6]
# Group  1  :  (6,)
#
# Sentences:  138
# Filtered Sentences:  14
# 14/14 [==============================] - 0s 186us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  1
# Group Sizes [53]
# Group  0  :  (53,)
#
# Sentences:  338
# Filtered Sentences:  44
# 44/44 [==============================] - 0s 151us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  2
# Group Sizes [37, 4]
# Group  0  :  (37,)
# Group  1  :  (4,)
#
# Sentences:  57
# Filtered Sentences:  20
# 20/20 [==============================] - 0s 145us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  1
# Group Sizes [62]
# Group  0  :  (62,)
#
# Sentences:  772
# Filtered Sentences:  86
# 86/86 [==============================] - 0s 137us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  3
# Group Sizes [4, 77, 4]
# Group  0  :  (4,)
# Group  1  :  (77,)
# Group  2  :  (4,)
#
# Sentences:  442
# Filtered Sentences:  75
# 75/75 [==============================] - 0s 147us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  3
# Group Sizes [325, 3, 4]
# Group  0  :  (325,)
# Group  1  :  (3,)
# Group  2  :  (4,)
# /home/urwa/miniconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys
# Sentences:  278
# Filtered Sentences:  83
# 83/83 [==============================] - 0s 162us/step
# Dataset Mentions:  15
# Cos Sim shape:  (15, 10348)
# Numer of Groups:  1
# Group Sizes [23]
# Group  0  :  (23,)
#
# Sentences:  123
# Filtered Sentences:  22
# 22/22 [==============================] - 0s 148us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  2
# Group Sizes [21, 50]
# Group  0  :  (21,)
# Group  1  :  (50,)
#
# Sentences:  230
# Filtered Sentences:  38
# 38/38 [==============================] - 0s 184us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  3
# Group Sizes [5, 47, 40]
# Group  0  :  (5,)
# Group  1  :  (47,)
# Group  2  :  (40,)
#
# Sentences:  245
# Filtered Sentences:  22
# 22/22 [==============================] - 0s 153us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  3
# Group Sizes [3, 1, 5]
# Group  0  :  (3,)
# Group  2  :  (5,)
#
# Sentences:  570
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 153us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  3
# Group Sizes [4, 3, 1]
# Group  0  :  (4,)
# Group  1  :  (3,)
#
# Sentences:  801
# Filtered Sentences:  88
# 88/88 [==============================] - 0s 131us/step
# Dataset Mentions:  12
# Cos Sim shape:  (12, 10348)
# Numer of Groups:  3
# Group Sizes [7, 1, 7]
# Group  0  :  (7,)
# Group  2  :  (7,)
#
# Sentences:  477
# Filtered Sentences:  76
# 76/76 [==============================] - 0s 148us/step
# Dataset Mentions:  0
# No mentions for file :  252.txt
# Sentences:  280
# Filtered Sentences:  48
# 48/48 [==============================] - 0s 167us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  3
# Group Sizes [3, 1, 7]
# Group  0  :  (3,)
# Group  2  :  (7,)
#
# Sentences:  370
# Filtered Sentences:  108
# 108/108 [==============================] - 0s 140us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  3
# Group Sizes [2, 5, 2]
# Group  0  :  (2,)
# Group  1  :  (5,)
# Group  2  :  (2,)
#
# Sentences:  254
# Filtered Sentences:  79
# 79/79 [==============================] - 0s 147us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  262.txt
#
# Sentences:  237
# Filtered Sentences:  35
# 35/35 [==============================] - 0s 229us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  5
# Group Sizes [7, 2, 2, 2, 3]
# Group  0  :  (7,)
# Group  1  :  (2,)
# Group  2  :  (2,)
# Group  3  :  (2,)
# Group  4  :  (3,)
#
# Sentences:  334
# Filtered Sentences:  67
# 67/67 [==============================] - 0s 167us/step
# Dataset Mentions:  0
# No mentions for file :  273.txt
# Sentences:  1500
# Filtered Sentences:  205
# 205/205 [==============================] - 0s 103us/step
# Dataset Mentions:  15
# Cos Sim shape:  (15, 10348)
# Numer of Groups:  7
# Group Sizes [402, 102, 26, 2, 1, 3, 14]
# Group  0  :  (402,)
# Group  1  :  (102,)
# Group  2  :  (26,)
# Group  3  :  (2,)
# Group  5  :  (3,)
# Group  6  :  (14,)
#
# Sentences:  1065
# Filtered Sentences:  216
# 216/216 [==============================] - 0s 122us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  6
# Group Sizes [6, 47, 20, 47, 23, 11]
# Group  0  :  (6,)
# Group  1  :  (47,)
# Group  2  :  (20,)
# Group  3  :  (47,)
# Group  4  :  (23,)
# Group  5  :  (11,)
#
# Sentences:  298
# Filtered Sentences:  43
# 43/43 [==============================] - 0s 159us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  2
# Group Sizes [36, 54]
# Group  0  :  (36,)
# Group  1  :  (54,)
#
# Sentences:  208
# Filtered Sentences:  71
# 71/71 [==============================] - 0s 177us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  3
# Group Sizes [1, 44, 20]
# Group  1  :  (44,)
# Group  2  :  (20,)
#
# Sentences:  510
# Filtered Sentences:  66
# 66/66 [==============================] - 0s 156us/step
# Dataset Mentions:  12
# Cos Sim shape:  (12, 10348)
# Numer of Groups:  1
# Group Sizes [36]
# Group  0  :  (36,)
#
# Sentences:  211
# Filtered Sentences:  52
# 52/52 [==============================] - 0s 179us/step
# Dataset Mentions:  30
# Cos Sim shape:  (30, 10348)
# Numer of Groups:  1
# Group Sizes [42]
# Group  0  :  (42,)
#
# Sentences:  347
# Filtered Sentences:  76
# 76/76 [==============================] - 0s 142us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [10]
# Group  0  :  (10,)
#
# Sentences:  292
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 151us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  1
# Group Sizes [34]
# Group  0  :  (34,)
#
# Sentences:  304
# Filtered Sentences:  75
# 75/75 [==============================] - 0s 137us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  1
# Group Sizes [38]
# Group  0  :  (38,)
#
# Sentences:  1035
# Filtered Sentences:  164
# 164/164 [==============================] - 0s 130us/step
# Dataset Mentions:  38
# Cos Sim shape:  (38, 10348)
# Numer of Groups:  2
# Group Sizes [108, 2]
# Group  0  :  (108,)
# Group  1  :  (2,)
#
# Sentences:  351
# Filtered Sentences:  31
# 31/31 [==============================] - 0s 131us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  3
# Group Sizes [3, 5, 1]
# Group  0  :  (3,)
# Group  1  :  (5,)
#
# Sentences:  103
# Filtered Sentences:  35
# 35/35 [==============================] - 0s 206us/step
# Dataset Mentions:  15
# Cos Sim shape:  (15, 10348)
# Numer of Groups:  1
# Group Sizes [69]
# Group  0  :  (69,)
#
# Sentences:  90
# Filtered Sentences:  21
# 21/21 [==============================] - 0s 151us/step
# Dataset Mentions:  0
# No mentions for file :  362.txt
# Sentences:  600
# Filtered Sentences:  99
# 99/99 [==============================] - 0s 141us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  3
# Group Sizes [20, 6, 4]
# Group  0  :  (20,)
# Group  1  :  (6,)
# Group  2  :  (4,)
#
# Sentences:  278
# Filtered Sentences:  95
# 95/95 [==============================] - 0s 146us/step
# Dataset Mentions:  27
# Cos Sim shape:  (27, 10348)
# Numer of Groups:  2
# Group Sizes [103, 11]
# Group  0  :  (103,)
# Group  1  :  (11,)
#
# Sentences:  263
# Filtered Sentences:  53
# 53/53 [==============================] - 0s 185us/step
# Dataset Mentions:  23
# Cos Sim shape:  (23, 10348)
# Numer of Groups:  2
# Group Sizes [120, 3]
# Group  0  :  (120,)
# Group  1  :  (3,)
#
# Sentences:  273
# Filtered Sentences:  31
# 31/31 [==============================] - 0s 140us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  1
# Group Sizes [52]
# Group  0  :  (52,)
#
# Sentences:  310
# Filtered Sentences:  126
# 126/126 [==============================] - 0s 127us/step
# Dataset Mentions:  16
# Cos Sim shape:  (16, 10348)
# Numer of Groups:  1
# Group Sizes [77]
# Group  0  :  (77,)
#
# Sentences:  316
# Filtered Sentences:  118
# 118/118 [==============================] - 0s 161us/step
# Dataset Mentions:  27
# Cos Sim shape:  (27, 10348)
# Numer of Groups:  2
# Group Sizes [111, 3]
# Group  0  :  (111,)
# Group  1  :  (3,)
#
# Sentences:  225
# Filtered Sentences:  77
# 77/77 [==============================] - 0s 151us/step
# Dataset Mentions:  19
# Cos Sim shape:  (19, 10348)
# Numer of Groups:  2
# Group Sizes [10, 1]
# Group  0  :  (10,)
#
# Sentences:  316
# Filtered Sentences:  51
# 51/51 [==============================] - 0s 200us/step
# Dataset Mentions:  0
# No mentions for file :  396.txt
# Sentences:  236
# Filtered Sentences:  42
# 42/42 [==============================] - 0s 186us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  2
# Group Sizes [18, 1]
# Group  0  :  (18,)
#
# Sentences:  343
# Filtered Sentences:  102
# 102/102 [==============================] - 0s 137us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  3
# Group Sizes [79, 2, 4]
# Group  0  :  (79,)
# Group  1  :  (2,)
# Group  2  :  (4,)
#
# Sentences:  364
# Filtered Sentences:  125
# 125/125 [==============================] - 0s 128us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  1
# Group Sizes [92]
# Group  0  :  (92,)
#
# Sentences:  383
# Filtered Sentences:  159
# 159/159 [==============================] - 0s 144us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  1
# Group Sizes [36]
# Group  0  :  (36,)
#
# Sentences:  235
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 185us/step
# Dataset Mentions:  12
# Cos Sim shape:  (12, 10348)
# Numer of Groups:  1
# Group Sizes [98]
# Group  0  :  (98,)
#
# Sentences:  422
# Filtered Sentences:  102
# 102/102 [==============================] - 0s 150us/step
# Dataset Mentions:  21
# Cos Sim shape:  (21, 10348)
# Numer of Groups:  7
# Group Sizes [1, 1, 17, 5, 72, 4, 5]
# Group  2  :  (17,)
# Group  3  :  (5,)
# Group  4  :  (72,)
# Group  5  :  (4,)
# Group  6  :  (5,)
#
# Sentences:  547
# Filtered Sentences:  127
# 127/127 [==============================] - 0s 124us/step
# Dataset Mentions:  30
# Cos Sim shape:  (30, 10348)
# Numer of Groups:  1
# Group Sizes [136]
# Group  0  :  (136,)
#
# Sentences:  338
# Filtered Sentences:  83
# 83/83 [==============================] - 0s 142us/step
# Dataset Mentions:  2
# Cos Sim shape:  (2, 10348)
# Numer of Groups:  2
# Group Sizes [43, 45]
# Group  0  :  (43,)
# Group  1  :  (45,)
#
# Sentences:  523
# Filtered Sentences:  68
# 68/68 [==============================] - 0s 144us/step
# Dataset Mentions:  20
# Cos Sim shape:  (20, 10348)
# Numer of Groups:  6
# Group Sizes [12, 15, 19, 12, 7, 2]
# Group  0  :  (12,)
# Group  1  :  (15,)
# Group  2  :  (19,)
# Group  3  :  (12,)
# Group  4  :  (7,)
# Group  5  :  (2,)
#
# Sentences:  312
# Filtered Sentences:  127
# 127/127 [==============================] - 0s 128us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  1
# Group Sizes [86]
# Group  0  :  (86,)
#
# Sentences:  323
# Filtered Sentences:  78
# 78/78 [==============================] - 0s 158us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  3
# Group Sizes [74, 5, 4]
# Group  0  :  (74,)
# Group  1  :  (5,)
# Group  2  :  (4,)
#
# Sentences:  277
# Filtered Sentences:  49
# 49/49 [==============================] - 0s 178us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  2
# Group Sizes [82, 1]
# Group  0  :  (82,)
#
# Sentences:  484
# Filtered Sentences:  54
# 54/54 [==============================] - 0s 142us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  2
# Group Sizes [10, 4]
# Group  0  :  (10,)
# Group  1  :  (4,)
#
# Sentences:  329
# Filtered Sentences:  117
# 117/117 [==============================] - 0s 199us/step
# Dataset Mentions:  44
# Cos Sim shape:  (44, 10348)
# Numer of Groups:  1
# Group Sizes [113]
# Group  0  :  (113,)
#
# Sentences:  372
# Filtered Sentences:  54
# 54/54 [==============================] - 0s 177us/step
# Dataset Mentions:  12
# Cos Sim shape:  (12, 10348)
# Numer of Groups:  5
# Group Sizes [4, 7, 2, 12, 3]
# Group  0  :  (4,)
# Group  1  :  (7,)
# Group  2  :  (2,)
# Group  3  :  (12,)
# Group  4  :  (3,)
#
# Sentences:  238
# Filtered Sentences:  38
# 38/38 [==============================] - 0s 183us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  3
# Group Sizes [27, 2, 4]
# Group  0  :  (27,)
# Group  1  :  (2,)
# Group  2  :  (4,)
#
# Sentences:  170
# Filtered Sentences:  32
# 32/32 [==============================] - 0s 139us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  2
# Group Sizes [6, 3]
# Group  0  :  (6,)
# Group  1  :  (3,)
#
# Sentences:  502
# Filtered Sentences:  113
# 113/113 [==============================] - 0s 131us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  3
# Group Sizes [26, 10, 17]
# Group  0  :  (26,)
# Group  1  :  (10,)
# Group  2  :  (17,)
#
# Sentences:  126
# Filtered Sentences:  20
# 20/20 [==============================] - 0s 149us/step
# Dataset Mentions:  2
# Cos Sim shape:  (2, 10348)
# Numer of Groups:  2
# Group Sizes [4, 58]
# Group  0  :  (4,)
# Group  1  :  (58,)
#
# Sentences:  310
# Filtered Sentences:  84
# 84/84 [==============================] - 0s 141us/step
# Dataset Mentions:  16
# Cos Sim shape:  (16, 10348)
# Numer of Groups:  1
# Group Sizes [94]
# Group  0  :  (94,)
#
# Sentences:  206
# Filtered Sentences:  57
# 57/57 [==============================] - 0s 181us/step
# Dataset Mentions:  17
# Cos Sim shape:  (17, 10348)
# Numer of Groups:  2
# Group Sizes [68, 3]
# Group  0  :  (68,)
# Group  1  :  (3,)
#
# Sentences:  417
# Filtered Sentences:  101
# 101/101 [==============================] - 0s 137us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  3
# Group Sizes [1, 2, 2]
# Group  1  :  (2,)
# Group  2  :  (2,)
#
# Sentences:  273
# Filtered Sentences:  52
# 52/52 [==============================] - 0s 249us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  2
# Group Sizes [4, 6]
# Group  0  :  (4,)
# Group  1  :  (6,)
#
# Sentences:  329
# Filtered Sentences:  65
# 65/65 [==============================] - 0s 156us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  1
# Group Sizes [6]
# Group  0  :  (6,)
#
# Sentences:  139
# Filtered Sentences:  23
# 23/23 [==============================] - 0s 155us/step
# Dataset Mentions:  0
# No mentions for file :  569.txt
# Sentences:  288
# Filtered Sentences:  80
# 80/80 [==============================] - 0s 144us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  1
# Group Sizes [80]
# Group  0  :  (80,)
#
# Sentences:  428
# Filtered Sentences:  171
# 171/171 [==============================] - 0s 129us/step
# Dataset Mentions:  22
# Cos Sim shape:  (22, 10348)
# Numer of Groups:  4
# Group Sizes [48, 160, 1, 1]
# Group  0  :  (48,)
# Group  1  :  (160,)
#
# Sentences:  576
# Filtered Sentences:  79
# 79/79 [==============================] - 0s 133us/step
# Dataset Mentions:  21
# Cos Sim shape:  (21, 10348)
# Numer of Groups:  7
# Group Sizes [10, 29, 4, 12, 5, 5, 12]
# Group  0  :  (10,)
# Group  1  :  (29,)
# Group  2  :  (4,)
# Group  3  :  (12,)
# Group  4  :  (5,)
# Group  5  :  (5,)
# Group  6  :  (12,)
#
# Sentences:  381
# Filtered Sentences:  146
# 146/146 [==============================] - 0s 140us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [35]
# Group  0  :  (35,)
#
# Sentences:  372
# Filtered Sentences:  71
# 71/71 [==============================] - 0s 152us/step
# Dataset Mentions:  0
# No mentions for file :  615.txt
# Sentences:  162
# Filtered Sentences:  29
# 29/29 [==============================] - 0s 147us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  1
# Group Sizes [34]
# Group  0  :  (34,)
#
# Sentences:  170
# Filtered Sentences:  26
# 26/26 [==============================] - 0s 154us/step
# Dataset Mentions:  13
# Cos Sim shape:  (13, 10348)
# Numer of Groups:  1
# Group Sizes [47]
# Group  0  :  (47,)
#
# Sentences:  435
# Filtered Sentences:  44
# 44/44 [==============================] - 0s 182us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  1
# Group Sizes [1]
#
# Sentences:  536
# Filtered Sentences:  61
# 61/61 [==============================] - 0s 143us/step
# Dataset Mentions:  15
# Cos Sim shape:  (15, 10348)
# Numer of Groups:  2
# Group Sizes [2, 1]
# Group  0  :  (2,)
#
# Sentences:  351
# Filtered Sentences:  76
# 76/76 [==============================] - 0s 141us/step
# Dataset Mentions:  24
# Cos Sim shape:  (24, 10348)
# Numer of Groups:  1
# Group Sizes [14]
# Group  0  :  (14,)
#
# Sentences:  370
# Filtered Sentences:  49
# 49/49 [==============================] - 0s 151us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  1
# Group Sizes [4]
# Group  0  :  (4,)
#
# Sentences:  393
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 143us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  3
# Group Sizes [18, 2, 1]
# Group  0  :  (18,)
# Group  1  :  (2,)
#
# Sentences:  300
# Filtered Sentences:  71
# 71/71 [==============================] - 0s 165us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  2
# Group Sizes [42, 3]
# Group  0  :  (42,)
# Group  1  :  (3,)
#
# Sentences:  233
# Filtered Sentences:  37
# 37/37 [==============================] - 0s 194us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  1
# Group Sizes [2]
# Group  0  :  (2,)
#
# Sentences:  341
# Filtered Sentences:  73
# 73/73 [==============================] - 0s 153us/step
# Dataset Mentions:  26
# Cos Sim shape:  (26, 10348)
# Numer of Groups:  1
# Group Sizes [97]
# Group  0  :  (97,)
#
# Sentences:  202
# Filtered Sentences:  45
# 45/45 [==============================] - 0s 202us/step
# Dataset Mentions:  20
# Cos Sim shape:  (20, 10348)
# Numer of Groups:  1
# Group Sizes [2]
# Group  0  :  (2,)
#
# Sentences:  428
# Filtered Sentences:  74
# 74/74 [==============================] - 0s 143us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  3
# Group Sizes [3, 68, 11]
# Group  0  :  (3,)
# Group  1  :  (68,)
# Group  2  :  (11,)
#
# Sentences:  431
# Filtered Sentences:  57
# 57/57 [==============================] - 0s 136us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  726.txt
#
# Sentences:  217
# Filtered Sentences:  60
# 60/60 [==============================] - 0s 168us/step
# Dataset Mentions:  20
# Cos Sim shape:  (20, 10348)
# Numer of Groups:  1
# Group Sizes [258]
# Group  0  :  (258,)
#
# Sentences:  445
# Filtered Sentences:  68
# 68/68 [==============================] - 0s 148us/step
# Dataset Mentions:  13
# Cos Sim shape:  (13, 10348)
# Numer of Groups:  1
# Group Sizes [4]
# Group  0  :  (4,)
#
# Sentences:  229
# Filtered Sentences:  65
# 65/65 [==============================] - 0s 154us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  1
# Group Sizes [42]
# Group  0  :  (42,)
#
# Sentences:  263
# Filtered Sentences:  38
# 38/38 [==============================] - 0s 202us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  2
# Group Sizes [32, 4]
# Group  0  :  (32,)
# Group  1  :  (4,)
#
# Sentences:  391
# Filtered Sentences:  58
# 58/58 [==============================] - 0s 151us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [38]
# Group  0  :  (38,)
#
# Sentences:  209
# Filtered Sentences:  88
# 88/88 [==============================] - 0s 136us/step
# Dataset Mentions:  12
# Cos Sim shape:  (12, 10348)
# Numer of Groups:  3
# Group Sizes [100, 41, 2]
# Group  0  :  (100,)
# Group  1  :  (41,)
# Group  2  :  (2,)
#
# Sentences:  187
# Filtered Sentences:  43
# 43/43 [==============================] - 0s 193us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  1
# Group Sizes [108]
# Group  0  :  (108,)
#
# Sentences:  107
# Filtered Sentences:  28
# 28/28 [==============================] - 0s 148us/step
# Dataset Mentions:  0
# No mentions for file :  760.txt
# Sentences:  533
# Filtered Sentences:  64
# 64/64 [==============================] - 0s 129us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  3
# Group Sizes [39, 417, 289]
# Group  0  :  (39,)
# Group  1  :  (417,)
# Group  2  :  (289,)
#
# Sentences:  269
# Filtered Sentences:  49
# 49/49 [==============================] - 0s 184us/step
# Dataset Mentions:  2
# Cos Sim shape:  (2, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  775.txt
#
# Sentences:  552
# Filtered Sentences:  77
# 77/77 [==============================] - 0s 147us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  3
# Group Sizes [33, 3, 1]
# Group  0  :  (33,)
# Group  1  :  (3,)
#
# Sentences:  123
# Filtered Sentences:  20
# 20/20 [==============================] - 0s 156us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  780.txt
#
# Sentences:  345
# Filtered Sentences:  47
# 47/47 [==============================] - 0s 150us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  1
# Group Sizes [49]
# Group  0  :  (49,)
#
# Sentences:  543
# Filtered Sentences:  50
# 50/50 [==============================] - 0s 139us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [1]
#
# Sentences:  633
# Filtered Sentences:  162
# 162/162 [==============================] - 0s 149us/step
# Dataset Mentions:  62
# Cos Sim shape:  (62, 10348)
# Numer of Groups:  2
# Group Sizes [85, 53]
# Group  0  :  (85,)
# Group  1  :  (53,)
#
# Sentences:  416
# Filtered Sentences:  79
# 79/79 [==============================] - 0s 143us/step
# Dataset Mentions:  2
# Cos Sim shape:  (2, 10348)
# Numer of Groups:  1
# Group Sizes [316]
# Group  0  :  (316,)
#
# Sentences:  198
# Filtered Sentences:  37
# 37/37 [==============================] - 0s 199us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  3
# Group Sizes [3, 1, 4]
# Group  0  :  (3,)
# Group  2  :  (4,)
#
# Sentences:  488
# Filtered Sentences:  54
# 54/54 [==============================] - 0s 135us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  1
# Group Sizes [2]
# Group  0  :  (2,)
#
# Sentences:  363
# Filtered Sentences:  87
# 87/87 [==============================] - 0s 140us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  3
# Group Sizes [23, 326, 58]
# Group  0  :  (23,)
# Group  1  :  (326,)
# Group  2  :  (58,)
#
# Sentences:  212
# Filtered Sentences:  24
# 24/24 [==============================] - 0s 173us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [84]
# Group  0  :  (84,)
#
# Sentences:  249
# Filtered Sentences:  33
# 33/33 [==============================] - 0s 214us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  837.txt
#
# Sentences:  188
# Filtered Sentences:  21
# 21/21 [==============================] - 0s 160us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [12]
# Group  0  :  (12,)
#
# Sentences:  385
# Filtered Sentences:  83
# 83/83 [==============================] - 0s 143us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  3
# Group Sizes [22, 5, 286]
# Group  0  :  (22,)
# Group  1  :  (5,)
# Group  2  :  (286,)
#
# Sentences:  196
# Filtered Sentences:  41
# 41/41 [==============================] - 0s 185us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [73]
# Group  0  :  (73,)
#
# Sentences:  153
# Filtered Sentences:  17
# 17/17 [==============================] - 0s 180us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  2
# Group Sizes [43, 85]
# Group  0  :  (43,)
# Group  1  :  (85,)
#
# Sentences:  335
# Filtered Sentences:  99
# 99/99 [==============================] - 0s 145us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  1
# Group Sizes [2]
# Group  0  :  (2,)
#
# Sentences:  449
# Filtered Sentences:  104
# 104/104 [==============================] - 0s 130us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  1
# Group Sizes [124]
# Group  0  :  (124,)
#
# Sentences:  318
# Filtered Sentences:  70
# 70/70 [==============================] - 0s 190us/step
# Dataset Mentions:  24
# Cos Sim shape:  (24, 10348)
# Numer of Groups:  1
# Group Sizes [185]
# Group  0  :  (185,)
#
# Sentences:  266
# Filtered Sentences:  102
# 102/102 [==============================] - 0s 152us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [1]
#
# Sentences:  319
# Filtered Sentences:  98
# 98/98 [==============================] - 0s 182us/step
# Dataset Mentions:  16
# Cos Sim shape:  (16, 10348)
# Numer of Groups:  2
# Group Sizes [31, 3]
# Group  0  :  (31,)
# Group  1  :  (3,)
#
# Sentences:  401
# Filtered Sentences:  60
# 60/60 [==============================] - 0s 168us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  2
# Group Sizes [15, 29]
# Group  0  :  (15,)
# Group  1  :  (29,)
#
# Sentences:  554
# Filtered Sentences:  74
# 74/74 [==============================] - 0s 140us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [4]
# Group  0  :  (4,)
#
# Sentences:  379
# Filtered Sentences:  115
# 115/115 [==============================] - 0s 145us/step
# Dataset Mentions:  22
# Cos Sim shape:  (22, 10348)
# Numer of Groups:  1
# Group Sizes [115]
# Group  0  :  (115,)
#
# Sentences:  152
# Filtered Sentences:  21
# 21/21 [==============================] - 0s 177us/step
# Dataset Mentions:  0
# No mentions for file :  939.txt
# Sentences:  177
# Filtered Sentences:  49
# 49/49 [==============================] - 0s 234us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  2
# Group Sizes [6, 78]
# Group  0  :  (6,)
# Group  1  :  (78,)
#
# Sentences:  252
# Filtered Sentences:  59
# 59/59 [==============================] - 0s 154us/step
# Dataset Mentions:  13
# Cos Sim shape:  (13, 10348)
# Numer of Groups:  4
# Group Sizes [41, 3, 25, 1]
# Group  0  :  (41,)
# Group  1  :  (3,)
# Group  2  :  (25,)
#
# Sentences:  303
# Filtered Sentences:  107
# 107/107 [==============================] - 0s 144us/step
# Dataset Mentions:  24
# Cos Sim shape:  (24, 10348)
# Numer of Groups:  3
# Group Sizes [134, 15, 54]
# Group  0  :  (134,)
# Group  1  :  (15,)
# Group  2  :  (54,)
#
# Sentences:  688
# Filtered Sentences:  83
# 83/83 [==============================] - 0s 151us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  2
# Group Sizes [51, 2]
# Group  0  :  (51,)
# Group  1  :  (2,)
#
# Sentences:  254
# Filtered Sentences:  71
# 71/71 [==============================] - 0s 157us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  2
# Group Sizes [6, 1]
# Group  0  :  (6,)
#
# Sentences:  399
# Filtered Sentences:  160
# 160/160 [==============================] - 0s 124us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  3
# Group Sizes [11, 1, 4]
# Group  0  :  (11,)
# Group  2  :  (4,)
#
# Sentences:  616
# Filtered Sentences:  85
# 85/85 [==============================] - 0s 140us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  2
# Group Sizes [80, 11]
# Group  0  :  (80,)
# Group  1  :  (11,)
#
# Sentences:  955
# Filtered Sentences:  138
# 138/138 [==============================] - 0s 133us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  1
# Group Sizes [3]
# Group  0  :  (3,)
#
# Sentences:  339
# Filtered Sentences:  85
# 85/85 [==============================] - 0s 149us/step
# Dataset Mentions:  17
# Cos Sim shape:  (17, 10348)
# Numer of Groups:  1
# Group Sizes [53]
# Group  0  :  (53,)
#
# Sentences:  299
# Filtered Sentences:  60
# 60/60 [==============================] - 0s 171us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  1
# Group Sizes [1]
#
# Sentences:  485
# Filtered Sentences:  127
# 127/127 [==============================] - 0s 123us/step
# Dataset Mentions:  40
# Cos Sim shape:  (40, 10348)
# Numer of Groups:  3
# Group Sizes [71, 4, 2]
# Group  0  :  (71,)
# Group  1  :  (4,)
# Group  2  :  (2,)
#
# Sentences:  212
# Filtered Sentences:  31
# 31/31 [==============================] - 0s 194us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [3]
# Group  0  :  (3,)
#
# Sentences:  242
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 191us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  4
# Group Sizes [1, 6, 9, 3]
# Group  1  :  (6,)
# Group  2  :  (9,)
# Group  3  :  (3,)
#
# Sentences:  299
# Filtered Sentences:  31
# 31/31 [==============================] - 0s 142us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  1
# Group Sizes [2]
# Group  0  :  (2,)
#
# Sentences:  542
# Filtered Sentences:  71
# 71/71 [==============================] - 0s 149us/step
# Dataset Mentions:  19
# Cos Sim shape:  (19, 10348)
# Numer of Groups:  1
# Group Sizes [27]
# Group  0  :  (27,)
#
# Sentences:  260
# Filtered Sentences:  45
# 45/45 [==============================] - 0s 195us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  3
# Group Sizes [88, 58, 9]
# Group  0  :  (88,)
# Group  1  :  (58,)
# Group  2  :  (9,)
#
# Sentences:  440
# Filtered Sentences:  67
# 67/67 [==============================] - 0s 160us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  3
# Group Sizes [1, 27, 2]
# Group  1  :  (27,)
# Group  2  :  (2,)
#
# Sentences:  331
# Filtered Sentences:  54
# 54/54 [==============================] - 0s 141us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  2
# Group Sizes [16, 20]
# Group  0  :  (16,)
# Group  1  :  (20,)
#
# Sentences:  210
# Filtered Sentences:  19
# 19/19 [==============================] - 0s 173us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  4
# Group Sizes [6, 4, 3, 2]
# Group  0  :  (6,)
# Group  1  :  (4,)
# Group  2  :  (3,)
# Group  3  :  (2,)
#
# Sentences:  254
# Filtered Sentences:  98
# 98/98 [==============================] - 0s 150us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  5
# Group Sizes [4, 5, 3, 9, 2]
# Group  0  :  (4,)
# Group  1  :  (5,)
# Group  2  :  (3,)
# Group  3  :  (9,)
# Group  4  :  (2,)
#
# Sentences:  632
# Filtered Sentences:  80
# 80/80 [==============================] - 0s 128us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  7
# Group Sizes [2, 1, 15, 1, 6, 1, 1]
# Group  0  :  (2,)
# Group  2  :  (15,)
# Group  4  :  (6,)
#
# Sentences:  225
# Filtered Sentences:  74
# 74/74 [==============================] - 0s 148us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  1
# Group Sizes [28]
# Group  0  :  (28,)
#
# Sentences:  410
# Filtered Sentences:  73
# 73/73 [==============================] - 0s 180us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [43]
# Group  0  :  (43,)
#
# Sentences:  377
# Filtered Sentences:  67
# 67/67 [==============================] - 0s 177us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  1
# Group Sizes [17]
# Group  0  :  (17,)
#
# Sentences:  377
# Filtered Sentences:  70
# 70/70 [==============================] - 0s 145us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  3
# Group Sizes [2, 1, 4]
# Group  0  :  (2,)
# Group  2  :  (4,)
#
# Sentences:  361
# Filtered Sentences:  67
# 67/67 [==============================] - 0s 151us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [5]
# Group  0  :  (5,)
#
# Sentences:  337
# Filtered Sentences:  50
# 50/50 [==============================] - 0s 146us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  2
# Group Sizes [28, 11]
# Group  0  :  (28,)
# Group  1  :  (11,)
#
# Sentences:  246
# Filtered Sentences:  47
# 47/47 [==============================] - 0s 180us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  1
# Group Sizes [4]
# Group  0  :  (4,)
#
# Sentences:  300
# Filtered Sentences:  33
# 33/33 [==============================] - 0s 199us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  4
# Group Sizes [67, 1, 1, 4]
# Group  0  :  (67,)
# Group  3  :  (4,)
#
# Sentences:  263
# Filtered Sentences:  48
# 48/48 [==============================] - 0s 182us/step
# Dataset Mentions:  0
# No mentions for file :  1197.txt
# Sentences:  329
# Filtered Sentences:  135
# 135/135 [==============================] - 0s 141us/step
# Dataset Mentions:  55
# Cos Sim shape:  (55, 10348)
# Numer of Groups:  1
# Group Sizes [123]
# Group  0  :  (123,)
#
# Sentences:  237
# Filtered Sentences:  57
# 57/57 [==============================] - 0s 185us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [34]
# Group  0  :  (34,)
#
# Sentences:  207
# Filtered Sentences:  40
# 40/40 [==============================] - 0s 184us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  4
# Group Sizes [1, 1, 3, 1]
# Group  2  :  (3,)
#
# Sentences:  252
# Filtered Sentences:  63
# 63/63 [==============================] - 0s 138us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  2
# Group Sizes [5, 4]
# Group  0  :  (5,)
# Group  1  :  (4,)
#
# Sentences:  269
# Filtered Sentences:  82
# 82/82 [==============================] - 0s 143us/step
# Dataset Mentions:  15
# Cos Sim shape:  (15, 10348)
# Numer of Groups:  1
# Group Sizes [63]
# Group  0  :  (63,)
#
# Sentences:  390
# Filtered Sentences:  101
# 101/101 [==============================] - 0s 144us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  2
# Group Sizes [155, 43]
# Group  0  :  (155,)
# Group  1  :  (43,)
#
# Sentences:  262
# Filtered Sentences:  37
# 37/37 [==============================] - 0s 232us/step
# Dataset Mentions:  15
# Cos Sim shape:  (15, 10348)
# Numer of Groups:  1
# Group Sizes [37]
# Group  0  :  (37,)
#
# Sentences:  275
# Filtered Sentences:  114
# 114/114 [==============================] - 0s 130us/step
# Dataset Mentions:  76
# Cos Sim shape:  (76, 10348)
# Numer of Groups:  1
# Group Sizes [262]
# Group  0  :  (262,)
#
# Sentences:  764
# Filtered Sentences:  89
# 89/89 [==============================] - 0s 135us/step
# Dataset Mentions:  16
# Cos Sim shape:  (16, 10348)
# Numer of Groups:  1
# Group Sizes [53]
# Group  0  :  (53,)
#
# Sentences:  179
# Filtered Sentences:  88
# 88/88 [==============================] - 0s 169us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  1
# Group Sizes [71]
# Group  0  :  (71,)
#
# Sentences:  256
# Filtered Sentences:  35
# 35/35 [==============================] - 0s 176us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  1
# Group Sizes [48]
# Group  0  :  (48,)
#
# Sentences:  367
# Filtered Sentences:  57
# 57/57 [==============================] - 0s 179us/step
# Dataset Mentions:  19
# Cos Sim shape:  (19, 10348)
# Numer of Groups:  1
# Group Sizes [68]
# Group  0  :  (68,)
#
# Sentences:  174
# Filtered Sentences:  26
# 26/26 [==============================] - 0s 171us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  1
# Group Sizes [46]
# Group  0  :  (46,)
#
# Sentences:  312
# Filtered Sentences:  88
# 88/88 [==============================] - 0s 136us/step
# Dataset Mentions:  38
# Cos Sim shape:  (38, 10348)
# Numer of Groups:  4
# Group Sizes [177, 4, 1, 4]
# Group  0  :  (177,)
# Group  1  :  (4,)
# Group  3  :  (4,)
#
# Sentences:  216
# Filtered Sentences:  65
# 65/65 [==============================] - 0s 157us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  1
# Group Sizes [51]
# Group  0  :  (51,)
#
# Sentences:  246
# Filtered Sentences:  70
# 70/70 [==============================] - 0s 150us/step
# Dataset Mentions:  24
# Cos Sim shape:  (24, 10348)
# Numer of Groups:  1
# Group Sizes [92]
# Group  0  :  (92,)
#
# Sentences:  262
# Filtered Sentences:  42
# 42/42 [==============================] - 0s 203us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  1
# Group Sizes [42]
# Group  0  :  (42,)
#
# Sentences:  246
# Filtered Sentences:  74
# 74/74 [==============================] - 0s 151us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  1
# Group Sizes [54]
# Group  0  :  (54,)
#
# Sentences:  198
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 181us/step
# Dataset Mentions:  2
# Cos Sim shape:  (2, 10348)
# Numer of Groups:  1
# Group Sizes [34]
# Group  0  :  (34,)
#
# Sentences:  247
# Filtered Sentences:  48
# 48/48 [==============================] - 0s 175us/step
# Dataset Mentions:  29
# Cos Sim shape:  (29, 10348)
# Numer of Groups:  3
# Group Sizes [89, 25, 20]
# Group  0  :  (89,)
# Group  1  :  (25,)
# Group  2  :  (20,)
#
# Sentences:  340
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 150us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [38]
# Group  0  :  (38,)
#
# Sentences:  266
# Filtered Sentences:  42
# 42/42 [==============================] - 0s 163us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  2
# Group Sizes [40, 1]
# Group  0  :  (40,)
#
# Sentences:  276
# Filtered Sentences:  112
# 112/112 [==============================] - 0s 138us/step
# Dataset Mentions:  49
# Cos Sim shape:  (49, 10348)
# Numer of Groups:  1
# Group Sizes [112]
# Group  0  :  (112,)
#
# Sentences:  153
# Filtered Sentences:  59
# 59/59 [==============================] - 0s 165us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  2
# Group Sizes [5, 6]
# Group  0  :  (5,)
# Group  1  :  (6,)
#
# Sentences:  219
# Filtered Sentences:  47
# 47/47 [==============================] - 0s 187us/step
# Dataset Mentions:  13
# Cos Sim shape:  (13, 10348)
# Numer of Groups:  1
# Group Sizes [55]
# Group  0  :  (55,)
#
# Sentences:  243
# Filtered Sentences:  33
# 33/33 [==============================] - 0s 206us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  1
# Group Sizes [40]
# Group  0  :  (40,)
#
# Sentences:  199
# Filtered Sentences:  45
# 45/45 [==============================] - 0s 182us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  4
# Group Sizes [9, 4, 41, 14]
# Group  0  :  (9,)
# Group  1  :  (4,)
# Group  2  :  (41,)
# Group  3  :  (14,)
#
# Sentences:  163
# Filtered Sentences:  56
# 56/56 [==============================] - 0s 186us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  1
# Group Sizes [89]
# Group  0  :  (89,)
#
# Sentences:  272
# Filtered Sentences:  79
# 79/79 [==============================] - 0s 150us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  1
# Group Sizes [44]
# Group  0  :  (44,)
#
# Sentences:  427
# Filtered Sentences:  108
# 108/108 [==============================] - 0s 139us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  1
# Group Sizes [36]
# Group  0  :  (36,)
#
# Sentences:  287
# Filtered Sentences:  43
# 43/43 [==============================] - 0s 205us/step
# Dataset Mentions:  18
# Cos Sim shape:  (18, 10348)
# Numer of Groups:  1
# Group Sizes [47]
# Group  0  :  (47,)
#
# Sentences:  416
# Filtered Sentences:  36
# 36/36 [==============================] - 0s 202us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  1
# Group Sizes [40]
# Group  0  :  (40,)
#
# Sentences:  249
# Filtered Sentences:  49
# 49/49 [==============================] - 0s 165us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  1
# Group Sizes [85]
# Group  0  :  (85,)
#
# Sentences:  1757
# Filtered Sentences:  315
# 315/315 [==============================] - 0s 103us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  1
# Group Sizes [70]
# Group  0  :  (70,)
#
# Sentences:  182
# Filtered Sentences:  51
# 51/51 [==============================] - 0s 187us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  1
# Group Sizes [86]
# Group  0  :  (86,)
#
# Sentences:  361
# Filtered Sentences:  88
# 88/88 [==============================] - 0s 142us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [36]
# Group  0  :  (36,)
#
# Sentences:  221
# Filtered Sentences:  71
# 71/71 [==============================] - 0s 202us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  1
# Group Sizes [35]
# Group  0  :  (35,)
#
# Sentences:  410
# Filtered Sentences:  86
# 86/86 [==============================] - 0s 141us/step
# Dataset Mentions:  12
# Cos Sim shape:  (12, 10348)
# Numer of Groups:  2
# Group Sizes [211, 1]
# Group  0  :  (211,)
#
# Sentences:  365
# Filtered Sentences:  51
# 51/51 [==============================] - 0s 141us/step
# Dataset Mentions:  17
# Cos Sim shape:  (17, 10348)
# Numer of Groups:  1
# Group Sizes [98]
# Group  0  :  (98,)
#
# Sentences:  193
# Filtered Sentences:  82
# 82/82 [==============================] - 0s 144us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  1
# Group Sizes [34]
# Group  0  :  (34,)
#
# Sentences:  180
# Filtered Sentences:  28
# 28/28 [==============================] - 0s 147us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  5
# Group Sizes [32, 41, 2, 1, 2]
# Group  0  :  (32,)
# Group  1  :  (41,)
# Group  2  :  (2,)
# Group  4  :  (2,)
#
# Sentences:  274
# Filtered Sentences:  47
# 47/47 [==============================] - 0s 153us/step
# Dataset Mentions:  2
# Cos Sim shape:  (2, 10348)
# Numer of Groups:  1
# Group Sizes [74]
# Group  0  :  (74,)
#
# Sentences:  98
# Filtered Sentences:  37
# 37/37 [==============================] - 0s 203us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  6
# Group Sizes [1, 15, 2, 4, 3, 2]
# Group  1  :  (15,)
# Group  2  :  (2,)
# Group  3  :  (4,)
# Group  4  :  (3,)
# Group  5  :  (2,)
#
# Sentences:  372
# Filtered Sentences:  114
# 114/114 [==============================] - 0s 122us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  3
# Group Sizes [1, 2, 2]
# Group  1  :  (2,)
# Group  2  :  (2,)
#
# Sentences:  157
# Filtered Sentences:  25
# 25/25 [==============================] - 0s 164us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  1
# Group Sizes [39]
# Group  0  :  (39,)
#
# Sentences:  193
# Filtered Sentences:  20
# 20/20 [==============================] - 0s 158us/step
# Dataset Mentions:  0
# No mentions for file :  1408.txt
# Sentences:  185
# Filtered Sentences:  58
# 58/58 [==============================] - 0s 187us/step
# Dataset Mentions:  30
# Cos Sim shape:  (30, 10348)
# Numer of Groups:  1
# Group Sizes [258]
# Group  0  :  (258,)
#
# Sentences:  193
# Filtered Sentences:  71
# 71/71 [==============================] - 0s 180us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  1
# Group Sizes [56]
# Group  0  :  (56,)
#
# Sentences:  379
# Filtered Sentences:  75
# 75/75 [==============================] - 0s 146us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  1423.txt
#
# Sentences:  196
# Filtered Sentences:  79
# 79/79 [==============================] - 0s 146us/step
# Dataset Mentions:  14
# Cos Sim shape:  (14, 10348)
# Numer of Groups:  6
# Group Sizes [1, 50, 1, 4, 7, 1]
# Group  1  :  (50,)
# Group  3  :  (4,)
# Group  4  :  (7,)
#
# Sentences:  281
# Filtered Sentences:  29
# 29/29 [==============================] - 0s 137us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  1
# Group Sizes [46]
# Group  0  :  (46,)
#
# Sentences:  209
# Filtered Sentences:  96
# 96/96 [==============================] - 0s 136us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  1
# Group Sizes [70]
# Group  0  :  (70,)
#
# Sentences:  326
# Filtered Sentences:  113
# 113/113 [==============================] - 0s 141us/step
# Dataset Mentions:  22
# Cos Sim shape:  (22, 10348)
# Numer of Groups:  1
# Group Sizes [111]
# Group  0  :  (111,)
#
# Sentences:  199
# Filtered Sentences:  64
# 64/64 [==============================] - 0s 164us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [53]
# Group  0  :  (53,)
#
# Sentences:  223
# Filtered Sentences:  143
# 143/143 [==============================] - 0s 134us/step
# Dataset Mentions:  46
# Cos Sim shape:  (46, 10348)
# Numer of Groups:  1
# Group Sizes [117]
# Group  0  :  (117,)
#
# Sentences:  267
# Filtered Sentences:  52
# 52/52 [==============================] - 0s 143us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  1
# Group Sizes [86]
# Group  0  :  (86,)
#
# Sentences:  261
# Filtered Sentences:  87
# 87/87 [==============================] - 0s 144us/step
# Dataset Mentions:  42
# Cos Sim shape:  (42, 10348)
# Numer of Groups:  1
# Group Sizes [105]
# Group  0  :  (105,)
#
# Sentences:  624
# Filtered Sentences:  143
# 143/143 [==============================] - 0s 134us/step
# Dataset Mentions:  24
# Cos Sim shape:  (24, 10348)
# Numer of Groups:  1
# Group Sizes [245]
# Group  0  :  (245,)
#
# Sentences:  220
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 169us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  1
# Group Sizes [66]
# Group  0  :  (66,)
#
# Sentences:  589
# Filtered Sentences:  128
# 128/128 [==============================] - 0s 131us/step
# Dataset Mentions:  22
# Cos Sim shape:  (22, 10348)
# Numer of Groups:  1
# Group Sizes [112]
# Group  0  :  (112,)
#
# Sentences:  336
# Filtered Sentences:  110
# 110/110 [==============================] - 0s 143us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  1
# Group Sizes [76]
# Group  0  :  (76,)
#
# Sentences:  268
# Filtered Sentences:  19
# 19/19 [==============================] - 0s 190us/step
# Dataset Mentions:  0
# No mentions for file :  1482.txt
# Sentences:  217
# Filtered Sentences:  100
# 100/100 [==============================] - 0s 147us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  2
# Group Sizes [67, 7]
# Group  0  :  (67,)
# Group  1  :  (7,)
#
# Sentences:  288
# Filtered Sentences:  85
# 85/85 [==============================] - 0s 145us/step
# Dataset Mentions:  17
# Cos Sim shape:  (17, 10348)
# Numer of Groups:  2
# Group Sizes [88, 1]
# Group  0  :  (88,)
#
# Sentences:  155
# Filtered Sentences:  27
# 27/27 [==============================] - 0s 152us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  1489.txt
#
# Sentences:  192
# Filtered Sentences:  81
# 81/81 [==============================] - 0s 140us/step
# Dataset Mentions:  21
# Cos Sim shape:  (21, 10348)
# Numer of Groups:  1
# Group Sizes [77]
# Group  0  :  (77,)
#
# Sentences:  315
# Filtered Sentences:  52
# 52/52 [==============================] - 0s 138us/step
# Dataset Mentions:  20
# Cos Sim shape:  (20, 10348)
# Numer of Groups:  1
# Group Sizes [70]
# Group  0  :  (70,)
#
# Sentences:  292
# Filtered Sentences:  48
# 48/48 [==============================] - 0s 148us/step
# Dataset Mentions:  8
# Cos Sim shape:  (8, 10348)
# Numer of Groups:  1
# Group Sizes [113]
# Group  0  :  (113,)
#
# Sentences:  549
# Filtered Sentences:  92
# 92/92 [==============================] - 0s 130us/step
# Dataset Mentions:  23
# Cos Sim shape:  (23, 10348)
# Numer of Groups:  2
# Group Sizes [110, 3]
# Group  0  :  (110,)
# Group  1  :  (3,)
#
# Sentences:  357
# Filtered Sentences:  143
# 143/143 [==============================] - 0s 144us/step
# Dataset Mentions:  26
# Cos Sim shape:  (26, 10348)
# Numer of Groups:  1
# Group Sizes [82]
# Group  0  :  (82,)
#
# Sentences:  307
# Filtered Sentences:  111
# 111/111 [==============================] - 0s 162us/step
# ...
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [26]
# Group  0  :  (26,)
#
# Sentences:  1018
# Filtered Sentences:  200
# 200/200 [==============================] - 0s 141us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [20]
# Group  0  :  (20,)
#
# Sentences:  514
# Filtered Sentences:  130
# 130/130 [==============================] - 0s 143us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  2923.txt
#
# Sentences:  969
# Filtered Sentences:  97
# 97/97 [==============================] - 0s 134us/step
# Dataset Mentions:  0
# No mentions for file :  2932.txt
# Sentences:  499
# Filtered Sentences:  93
# 93/93 [==============================] - 0s 128us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  2
# Group Sizes [12, 16]
# Group  0  :  (12,)
# Group  1  :  (16,)
#
# Sentences:  768
# Filtered Sentences:  168
# 168/168 [==============================] - 0s 121us/step
# Dataset Mentions:  2
# Cos Sim shape:  (2, 10348)
# Numer of Groups:  2
# Group Sizes [16, 1]
# Group  0  :  (16,)
#
# Sentences:  905
# Filtered Sentences:  197
# 197/197 [==============================] - 0s 139us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  2
# Group Sizes [7, 3]
# Group  0  :  (7,)
# Group  1  :  (3,)
#
# Sentences:  1238
# Filtered Sentences:  199
# 199/199 [==============================] - 0s 132us/step
# Dataset Mentions:  41
# Cos Sim shape:  (41, 10348)
# Numer of Groups:  1
# Group Sizes [62]
# Group  0  :  (62,)
# Sentences:  330
# Filtered Sentences:  87
# 87/87 [==============================] - 0s 140us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  1
# Group Sizes [3]
# Group  0  :  (3,)
#
# Sentences:  262
# Filtered Sentences:  53
# 53/53 [==============================] - 0s 183us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  2982.txt
#
# Sentences:  334
# Filtered Sentences:  53
# 53/53 [==============================] - 0s 148us/step
# Dataset Mentions:  19
# Cos Sim shape:  (19, 10348)
# Numer of Groups:  2
# Group Sizes [130, 7]
# Group  0  :  (130,)
# Group  1  :  (7,)
#
# Sentences:  447
# Filtered Sentences:  135
# 135/135 [==============================] - 0s 139us/step
# Dataset Mentions:  23
# Cos Sim shape:  (23, 10348)
# Numer of Groups:  3
# Group Sizes [464, 292, 3]
# Group  0  :  (464,)
# Group  1  :  (292,)
# Group  2  :  (3,)
#
# Sentences:  344
# Filtered Sentences:  115
# 115/115 [==============================] - 0s 136us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  1
# Group Sizes [27]
# Group  0  :  (27,)
#
# Sentences:  200
# Filtered Sentences:  58
# 58/58 [==============================] - 0s 229us/step
# Dataset Mentions:  6
# Cos Sim shape:  (6, 10348)
# Numer of Groups:  1
# Group Sizes [82]
# Group  0  :  (82,)
#
# Sentences:  291
# Filtered Sentences:  60
# 60/60 [==============================] - 0s 146us/step
# Dataset Mentions:  23
# Cos Sim shape:  (23, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  3008.txt
#
# Sentences:  228
# Filtered Sentences:  66
# 66/66 [==============================] - 0s 160us/step
# Dataset Mentions:  28
# Cos Sim shape:  (28, 10348)
# Numer of Groups:  4
# Group Sizes [4, 3, 1, 7]
# Group  0  :  (4,)
# Group  1  :  (3,)
# Group  3  :  (7,)
#
# Sentences:  422
# Filtered Sentences:  46
# 46/46 [==============================] - 0s 160us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  1
# Group Sizes [13]
# Group  0  :  (13,)
#
# Sentences:  234
# Filtered Sentences:  51
# 51/51 [==============================] - 0s 173us/step
# Dataset Mentions:  4
# Cos Sim shape:  (4, 10348)
# Numer of Groups:  0
# Group Sizes []
# No dataset matched mentions for file :  3028.txt
#
# Sentences:  336
# Filtered Sentences:  107
# 107/107 [==============================] - 0s 144us/step
# Dataset Mentions:  18
# Cos Sim shape:  (18, 10348)
# Numer of Groups:  2
# Group Sizes [84, 38]
# Group  0  :  (84,)
# Group  1  :  (38,)
#
# Sentences:  229
# Filtered Sentences:  57
# 57/57 [==============================] - 0s 282us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  1
# Group Sizes [42]
# Group  0  :  (42,)
#
# Sentences:  432
# Filtered Sentences:  81
# 81/81 [==============================] - 0s 183us/step
# Dataset Mentions:  26
# Cos Sim shape:  (26, 10348)
# Numer of Groups:  2
# Group Sizes [4, 8]
# Group  0  :  (4,)
# Group  1  :  (8,)
#
# Sentences:  188
# Filtered Sentences:  28
# 28/28 [==============================] - 0s 149us/step
# Dataset Mentions:  11
# Cos Sim shape:  (11, 10348)
# Numer of Groups:  1
# Group Sizes [43]
# Group  0  :  (43,)
#
# Sentences:  140
# Filtered Sentences:  39
# 39/39 [==============================] - 0s 189us/step
# Dataset Mentions:  18
# Cos Sim shape:  (18, 10348)
# Numer of Groups:  2
# Group Sizes [353, 40]
# Group  0  :  (353,)
# Group  1  :  (40,)
#
# Sentences:  156
# Filtered Sentences:  67
# 67/67 [==============================] - 0s 201us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  1
# Group Sizes [45]
# Group  0  :  (45,)
#
# Sentences:  381
# Filtered Sentences:  79
# 79/79 [==============================] - 0s 176us/step
# Dataset Mentions:  15
# Cos Sim shape:  (15, 10348)
# Numer of Groups:  1
# Group Sizes [91]
# Group  0  :  (91,)
#
# Sentences:  331
# Filtered Sentences:  49
# 49/49 [==============================] - 0s 182us/step
# Dataset Mentions:  17
# Cos Sim shape:  (17, 10348)
# Numer of Groups:  4
# Group Sizes [6, 8, 3, 3]
# Group  0  :  (6,)
# Group  1  :  (8,)
# Group  2  :  (3,)
# Group  3  :  (3,)
#
# Sentences:  415
# Filtered Sentences:  72
# 72/72 [==============================] - 0s 152us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  1
# Group Sizes [2]
# Group  0  :  (2,)
#
# Sentences:  533
# Filtered Sentences:  161
# 161/161 [==============================] - 0s 142us/step
# Dataset Mentions:  38
# Cos Sim shape:  (38, 10348)
# Numer of Groups:  7
# Group Sizes [219, 3, 1, 1, 12, 1, 1]
# Group  0  :  (219,)
# Group  1  :  (3,)
# Group  4  :  (12,)
#
# Sentences:  373
# Filtered Sentences:  42
# 42/42 [==============================] - 0s 150us/step
# Dataset Mentions:  1
# Cos Sim shape:  (1, 10348)
# Numer of Groups:  1
# Group Sizes [9]
# Group  0  :  (9,)
#
# Sentences:  240
# Filtered Sentences:  44
# 44/44 [==============================] - 0s 195us/step
# Dataset Mentions:  10
# Cos Sim shape:  (10, 10348)
# Numer of Groups:  1
# Group Sizes [100]
# Group  0  :  (100,)
#
# Sentences:  440
# Filtered Sentences:  102
# 102/102 [==============================] - 0s 144us/step
# Dataset Mentions:  23
# Cos Sim shape:  (23, 10348)
# Numer of Groups:  1
# Group Sizes [119]
# Group  0  :  (119,)
#
# Sentences:  330
# Filtered Sentences:  61
# 61/61 [==============================] - 0s 135us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  1
# Group Sizes [86]
# Group  0  :  (86,)
#
# Sentences:  524
# Filtered Sentences:  66
# 66/66 [==============================] - 0s 157us/step
# Dataset Mentions:  9
# Cos Sim shape:  (9, 10348)
# Numer of Groups:  5
# Group Sizes [10, 2, 5, 3, 100]
# Group  0  :  (10,)
# Group  1  :  (2,)
# Group  2  :  (5,)
# Group  3  :  (3,)
# Group  4  :  (100,)
#
# Sentences:  261
# Filtered Sentences:  74
# 74/74 [==============================] - 0s 152us/step
# Dataset Mentions:  5
# Cos Sim shape:  (5, 10348)
# Numer of Groups:  5
# Group Sizes [12, 2, 28, 2, 10]
# Group  0  :  (12,)
# Group  1  :  (2,)
# Group  2  :  (28,)
# Group  3  :  (2,)
# Group  4  :  (10,)
#
# Sentences:  380
# Filtered Sentences:  144
# 144/144 [==============================] - 0s 149us/step
# Dataset Mentions:  7
# Cos Sim shape:  (7, 10348)
# Numer of Groups:  3
# Group Sizes [15, 14, 30]
# Group  0  :  (15,)
# Group  1  :  (14,)
# Group  2  :  (30,)
#
# Sentences:  525
# Filtered Sentences:  50
# 50/50 [==============================] - 0s 137us/step
# Dataset Mentions:  3
# Cos Sim shape:  (3, 10348)
# Numer of Groups:  1
# Group Sizes [8]
# Group  0  :  (8,)
#
# ResultDf Length :  3328
# TrueLabel Length :  1020
# 206
# Intersection :  405
# {(1168, 902), (1583, 500), (1663, 976), (513, 595), (2274, 438), (2317, 615), (3067, 389), (236, 438), (119, 338), (1006, 840), (1204, 771), (338, 482), (2394, 1120), (1894, 481), (1673, 483), (3106, 382), (2324, 618), (2609, 481), (2337, 807), (389, 481), (2233, 1032), (2567, 438), (1509, 482), (2901, 306), (2340, 1099), (938, 738), (2102, 382), (543, 651), (2801, 488), (2337, 621), (2692, 1201), (2890, 339), (2013, 481), (1779, 482), (1583, 509), (1619, 483), (1907, 438), (631, 376), (1603, 484), (2317, 608), (3067, 410), (1691, 481), (3063, 80), (772, 40), (2554, 668), (2692, 1134), (1576, 500), (671, 204), (2913, 306), (3063, 78), (2434, 438), (2306, 578), (479, 382), (520, 613), (2324, 625), (2680, 671), (1485, 481), (2995, 764), (2298, 1089), (391, 524), (2324, 607), (2399, 485), (720, 381), (870, 382), (1437, 481), (2330, 613), (2361, 635), (1084, 558), (1971, 438), (738, 258), (597, 710), (1248, 382), (1398, 939), (1425, 400), (2051, 484), (1583, 506), (2337, 600), (209, 384), (2147, 459), (3063, 41), (1209, 378), (526, 608), (789, 261), (209, 410), (1357, 382), (1576, 507), (1583, 517), (1860, 482), (817, 399), (2917, 1283), (1784, 382), (434, 438), (2118, 488), (2765, 1240), (2324, 632), (1240, 483), (1410, 470), (341, 485), (2324, 614), (2384, 1114), (3016, 455), (216, 415), (1084, 549), (475, 567), (2309, 606), (520, 600), (526, 607), (458, 484), (2196, 438), (1296, 382), (1486, 484), (181, 279), (216, 389), (1663, 975), (2118, 892), (3039, 396), (3067, 424), (445, 537), (216, 427), (1663, 981), (1806, 482), (3108, 382), (581, 382), (2021, 484), (1241, 382), (1006, 839), (2765, 1233), (624, 736), (1353, 382), (1784, 482), (1823, 482), (1135, 457), (2540, 1162), (638, 377), (2373, 1111), (1084, 454), (2307, 581), (2324, 621), (2298, 1085), (2337, 624), (520, 607), (1398, 933), (1362, 391), (2338, 1098), (939, 827), (2352, 1017), (1988, 482), (1506, 484), (1677, 523), (3077, 382), (252, 447), (1583, 502), (3028, 748), (3067, 417), (1663, 978), (2164, 436), (1423, 480), (569, 673), (479, 482), (2801, 1145), (1540, 481), (2399, 458), (1046, 834), (2318, 618), (1673, 481), (2405, 799), (835, 45), (759, 380), (2609, 489), (520, 608), (2324, 628), (1587, 494), (910, 219), (2405, 436), (2560, 521), (350, 484), (1508, 481), (2051, 481), (373, 482), (1583, 511), (2801, 1249), (1504, 382), (1543, 488), (3067, 412), (3063, 82), (827, 800), (772, 42), (1478, 484), (2166, 1027), (1295, 803), (1576, 502), (2944, 339), (3008, 1293), (3063, 72), (772, 48), (1813, 382), (2306, 576), (2330, 607), (1798, 482), (2288, 597), (2609, 482), (520, 615), (748, 395), (440, 481), (2324, 627), (748, 380), (1241, 483), (1682, 481), (2040, 382), (362, 517), (2324, 601), (1425, 380), (1410, 382), (216, 410), (1084, 552), (2412, 882), (1398, 937), (3002, 382), (3142, 536), (1486, 483), (182, 394), (216, 384), (2337, 606), (2284, 597), (2579, 671), (209, 390), (1489, 487), (1329, 382), (837, 568), (2597, 1176), (2985, 394), (777, 381), (1576, 509), (836, 802), (2124, 1014), (886, 382), (2765, 1238), (1932, 482), (2324, 634), (997, 753), (1550, 516), (2324, 608), (2267, 1063), (2040, 482), (2330, 618), (1084, 551), (203, 377), (2309, 604), (520, 602), (526, 605), (1184, 567), (1362, 394), (442, 536), (374, 482), (759, 400), (674, 444), (1663, 969), (259, 449), (1873, 481), (1807, 481), (1583, 491), (2801, 1269), (756, 626), (2021, 482), (2317, 618), (825, 48), (747, 382), (119, 337), (1204, 472), (311, 395), (1540, 484), (2682, 671), (2318, 609), (772, 76), (3063, 76), (2232, 588), (2317, 606), (2324, 623), (2249, 537), (1473, 483), (2298, 1083), (2913, 1283), (845, 376), (350, 483), (2025, 482), (2982, 476), (1447, 484), (2923, 320), (960, 779), (2309, 623), (1257, 914), (2797, 1257), (2013, 484), (1779, 481), (1445, 482), (1825, 382), (2801, 1262), (3067, 419), (1603, 483), (3067, 409), (2168, 645), (500, 587), (772, 45), (1006, 844), (1478, 483), (2307, 575), (2364, 692), (1540, 483), (365, 382), (1576, 497), (1636, 482), (3063, 77), (835, 47), (2 ...
# {(1796, 391), (1798, 423), (1540, 6579), (365, 9987), (2259, 3334), (526, 620), (581, 377), (2317, 615), (1996, 382), (2995, 3309), (442, 2887), (1673, 805), (1673, 760), (2020, 482), (2394, 1120), (1432, 261), (1673, 950), (1932, 3283), (2345, 1015), (1939, 8184), (434, 5872), (756, 1095), (1329, 760), (2233, 1032), (281, 3107), (1672, 805), (1084, 102), (1670, 464), (2398, 486), (1414, 260), (2164, 858), (1540, 5414), (1844, 950), (2020, 3283), (2337, 621), (2680, 7493), (1504, 262), (1509, 470), (1825, 394), (1691, 481), (2309, 1093), (1486, 261), (938, 8423), (2204, 585), (1364, 8139), (2102, 3283), (2251, 2144), (2758, 9987), (2347, 5428), (2758, 3832), (434, 7465), (1447, 426), (2306, 578), (1748, 786), (1950, 1453), (1603, 5413), (281, 989), (1112, 6931), (281, 3487), (2307, 599), (2324, 607), (237, 1583), (2367, 3315), (2551, 5309), (3142, 981), (1437, 481), (1534, 2257), (1248, 382), (2051, 484), (751, 527), (835, 4430), (756, 762), (3016, 396), (1663, 6532), (2249, 597), (2340, 1298), (1813, 759), (1932, 964), (281, 450), (295, 7453), (1784, 382), (1414, 786), (458, 395), (1037, 622), (1437, 542), (1932, 6425), (1830, 736), (2551, 9128), (1996, 760), (1540, 6425), (570, 612), (1603, 422), (2011, 5413), (2324, 614), (2384, 1114), (2434, 8963), (2682, 2539), (515, 3364), (1673, 5415), (886, 6452), (2274, 3838), (923, 10340), (1813, 394), (1540, 771), (1748, 260), (2340, 6420), (1841, 260), (756, 624), (1932, 963), (2352, 486), (281, 459), (1241, 382), (1939, 70), (1334, 859), (1813, 950), (1907, 464), (2259, 5872), (1006, 839), (974, 481), (997, 475), (2318, 611), (2130, 8136), (638, 377), (1996, 759), (2284, 87), (624, 423), (2307, 581), (2324, 621), (458, 261), (521, 622), (1187, 6733), (1204, 482), (1673, 5416), (2337, 624), (671, 464), (1822, 4328), (2338, 1098), (910, 1307), (2765, 6749), (1822, 261), (1543, 1833), (1939, 3733), (3077, 382), (2528, 1690), (2424, 1062), (1037, 1092), (2204, 8508), (281, 460), (1807, 394), (2412, 2392), (1813, 260), (2434, 8140), (1672, 391), (2509, 8308), (1381, 477), (1822, 760), (155, 375), (236, 5428), (2118, 946), (2318, 618), (570, 630), (2324, 628), (2606, 8216), (2610, 785), (1822, 950), (1365, 484), (1400, 7490), (1504, 5439), (1296, 3417), (2890, 375), (2434, 7406), (515, 987), (1666, 776), (1779, 484), (2394, 611), (2021, 6392), (592, 9948), (350, 1637), (1251, 5415), (2509, 5428), (2997, 114), (2434, 8135), (2324, 87), (2509, 440), (1841, 391), (1931, 261), (2011, 6392), (3063, 7465), (1796, 909), (1813, 382), (2324, 627), (440, 481), (974, 756), (1099, 8184), (1662, 8423), (1065, 4633), (2011, 8509), (400, 542), (1425, 4331), (738, 139), (748, 5413), (526, 602), (1187, 828), (281, 10305), (281, 2484), (1336, 482), (1666, 771), (1666, 470), (1684, 380), (2298, 5139), (789, 760), (1806, 380), (1796, 5415), (1540, 911), (1841, 2772), (458, 786), (350, 426), (1943, 4736), (1666, 1305), (923, 581), (1682, 786), (1807, 964), (1613, 148), (2318, 628), (2124, 1014), (1672, 260), (570, 632), (2324, 634), (1006, 2128), (2329, 625), (3063, 426), (997, 753), (682, 481), (2330, 618), (2995, 299), (526, 605), (259, 7493), (1830, 805), (1540, 426), (1873, 1637), (1825, 4355), (2233, 9163), (398, 464), (1432, 786), (1603, 759), (259, 449), (2196, 5428), (1666, 909), (2288, 756), (526, 1290), (428, 481), (747, 382), (1504, 909), (1603, 395), (1822, 470), (2329, 634), (434, 5648), (2682, 671), (1538, 771), (636, 768), (2265, 482), (2340, 2840), (529, 592), (1251, 911), (2330, 629), (1473, 483), (2708, 4375), (374, 1526), (1673, 426), (2309, 623), (1257, 914), (281, 9865), (1211, 768), (1931, 5415), (1763, 482), (1394, 7491), (2509, 8216), (1748, 760), (1841, 426), (203, 2057), (3067, 409), (500, 587), (597, 1123), (1509, 6579), (1478, 483), (1996, 786), (2758, 8789), (835, 5606), (365, 382), (212, 1453), (458, 5439), (972, 5301), (1830, 964), (2309, 5406), (1666, 5439), (2161, 6526), (738, 148), (1473, 484), (671, 6619), (671, 3993), (2540, 8221), (2259, 2334), (2509, 8651), (268, 5428), ...
# CPU times: user 32min 42s, sys: 2min 11s, total: 34min 54s
# Wall time: 12min 14s

# %%
evalDf = pd.DataFrame(parameterResults)
evalDf.sort_values(by='fscore', axis=0, ascending=False)
