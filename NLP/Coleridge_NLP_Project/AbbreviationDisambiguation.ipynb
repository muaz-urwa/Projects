# %% [markdown]
# ### Abbreviation Expansion
#
# We discovered that abbreviation expansion was extremely important becuase the text refers to datasets as abbreviations mostly. Abbreviation expansion module inhanced the accuracy of our sentence classification model by 7 %. When there are multiple possible expansions True expansion of the abbreviation should also take into consideration the context of the text. Otherwise it will lead to bias in the model. Example being WLS which can be 'Wisconsin Longitudinal Study' or 'Weighted Least Square'. We did not handle this for now but it is crucial in any future work.
#
# We developed a abbreviation expansion dictionary from the datsets metadata file. It was conststurcted using following approach:
# - All the abbreviations were detected using regex matching
# - N-Grams of the relevant length were extracted from the description an metions (both with and without stop word removal)
# - Abbreviation and intials of N-grams were matched to create possible expansions
# - Lemmatization resolved for the muliple expansion caused by  'X study' and 'X studies'
# - Manual pruning resolved the remaininig multiple expansions
#
# We also attempted to create an abbreviation dictionary for the whole corpus, but it resulted in a lot of bogus expansions that would induce bias in the model. So we did not use it. But it is certianly something that can be worked on in future.

# %%
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
import string
import json
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import re

# %%
import spacy
# Load the large English NLP model
nlp = spacy.load('en_core_web_lg')

# %%
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
file = 'data_sets.json'
directory = '/home/urwa/Documents/Coleridge/ProjectFiles/train_test/train_test/'
text = load_doc(directory+file)

loaded_json = json.loads(text)

# %%
## Checking if an abbreviation corresponds to a geographical location
def IsLocation(txt):
    doc = nlp(txt)
    return len(doc.ents) > 0 and doc.ents[0].label_ == 'GPE'

# %%
## Find abbreviation using Regex
def findAbbreviation(mentions):
    regex = r"\b[A-Z][A-Z]+\b"
    abbreviations = []
    for m in mentions:
        abbreviations += re.findall(regex, m)
    abbreviations = [w for w in abbreviations if not IsLocation(w)]

    abbreviations = [w for w in abbreviations if len(w)>2]
    
    # filter special words
    special_words = ['study','survey','data', 'research', 'surveys', 'studies','ii' ]
    abbreviations = [w for w in abbreviations if not w.lower() in special_words]
    
    return abbreviations

# %%
# turn a doc into clean tokens
def clean_mention(doc):
    
    doc = doc.replace('- ','')
    doc = doc.replace('-',' ')
    
    # split into tokens by white space
    tokens = doc.split()
    
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    
    # make lower case
    tokens = [word.lower() for word in tokens]  
    
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    
    return ' '.join(tokens)

# %%
### Return N grams in the specified range
def findExpansions(mentions,minL=2,maxL=10):
    # each field as a sentence
    docs = [clean_mention(m) for m in mentions]
    docs = [d for d in docs if len(d.split())>1]
    
    if len(docs) > 0:
    
        # create the tokenizer
        vectorizer = TfidfVectorizer(ngram_range=(minL, maxL))

        # fit the tokenizer on the documents
        tfidVec = vectorizer.fit(docs)
    
        return vectorizer.get_feature_names()
    
    else:
        return []

# %%
# Match initials to abbreviation
def matchInitial(abb,expansion):
    initials = ''.join([w[0] for w in expansion.split()])
    return abb == initials

# %%
# Find the abbreviation in possible expansions
def expandAbbreviation(key, worchChunks):
    key = key.lower()
    candidates = [w for w in worchChunks if len(w.split()) == len(key)]
    matches = []
    for c in candidates:
        if matchInitial(key,c):
            matches.append(c)
    return matches

# %%
abbDict = {}
i=0
for d in loaded_json:
    mentions = d['mention_list']
    if len(mentions) > 0:
        abbs = findAbbreviation(mentions)
        expansions = findExpansions(mentions,minL=2,maxL=10)
        for ab in abbs:
            matches = expandAbbreviation(ab,expansions)
            if len(matches) > 0:
                if ab in abbDict:
                    abbDict[ab] = list(set(abbDict[ab] + matches))
                else:
                    abbDict[ab] = list(set(matches))
    i += 1

# %%
len(abbDict)
# Out:
# 204

# %%
abbDict
# Out:
# {'SRC': ['survey research center'],
#  'CPS': ['current population studies',
#   'center political studies',
#   'current population surveys',
#   'current population survey',
#   'current population study'],
#  'NES': ['national election studies', 'national election study'],
#  'SIPP': ['survey income program participation',
#   'surveys income program participation'],
#  'PSID': ['panel study income dynamics'],
#  'ANES': ['american national election studies'],
#  'HIS': ['health interview survey', 'health interview surveys'],
#  'NHIS': ['national health interview surveymultiple',
#   'national health interview surveys',
#   'national health interview survey'],
#  'NCHS': ['national center health statistics'],
#  'FBI': ['federal bureau investigation', 'federal bureau investigations'],
#  'UCR': ['uniform crime reports',
#   'uniform crime report',
#   'uniform crime reporting'],
#  'NLS': ['national longitudinal survey'],
#  'NLSOM': ['national longitudinal survey older men'],
#  'MFI': ['monetary financial institutions'],
#  'MIR': ['mfi interest rate'],
#  'ITS': ['international trade services'],
#  'SITS': ['statistics international trade services'],
#  'SHS': ['securities holdings statistics'],
#  'PHF': ['panel household finances'],
#  'FDI': ['foreign direct investments', 'foreign direct investment'],
#  'RDSC': ['research data service centre'],
#  'EPESE': ['established populations epidemiological studies elderly',
#   'established population epidemiologic studies elderly',
#   'established populations epidemiologic study elderly',
#   'established population epidemiological study elderly',
#   'established population epidemiological studies elderly',
#   'established population epidemiologic study elderly',
#   'established populations epidemiologic studies elderly',
#   'established populations epidemiologic studies elderlyepeseprogram',
#   'established populations epidemiological study elderly'],
#  'HEPESE': ['hispanic established population epidemiological studies elderly',
#   'hispanic established population epidemiologic studies elderly',
#   'hispanic established populations epidemiological study elderly',
#   'hispanic established population epidemiological study elderly',
#   'hispanic established populations epidemiologic study elderly',
#   'hispanic established populations epidemiologic studies elderly',
#   'hispanic established population epidemiologic study elderly'],
#  'HRS': ['health retirement surve',
#   'health retirement study',
#   'health retirement survey'],
#  'NLTCS': ['national long term care surveys',
#   'national long term care survey'],
#  'NLTC': ['national long term care'],
#  'NHEFS': ['national health epidemiologic follow study'],
#  'NEFS': ['nhanes epidemiologic follow study',
#   'nhanes epidemiological follow study',
#   'nhanes epidemiologic follow studies',
#   'national epidemiologic follow studies',
#   'national epidemiologic follow study',
#   'nhanes epidemiologic followup study',
#   'nutrition epidemiologic follow study',
#   'nhanes epidemiologic follow survey',
#   'nhanes epidemiologic followup survey',
#   'nutrition examination follow study',
#   'nhanes epldemiologic fouownp study'],
#  'NIA': ['national institute aging', 'national institute agings'],
#  'CDC': ['centers disease control', 'center disease control'],
#  'NHDS': ['nchs hospital discharge survey',
#   'national hospital discharge survey',
#   'national hospitalization discharge survey',
#   'naional hospital discharge survey'],
#  'ECA': ['epidemiologic catchment area'],
#  'NIMH': ['national institutes mental health',
#   'national institute mental health'],
#  'ACL': ['americans changing lives'],
#  'HES': ['health examination survey',
#   'health examination surveys',
#   'health examination surrey'],
#  'NMES': ['national medical expenditure survey'],
#  'NSFH': ['national survey families households'],
#  'EVS': ['european value surveys',
#   'european values surveys',
#   'europeanworld values surveys'],
#  'WVS': ['world value surveys', 'world values surveys', 'world values survey'],
#  'DAWN': ['drug abuse warning network'],
#  'ALSA': ['australian longitudinal study ageing'],
#  'PHDCN': ['project human development chicago neighborhoods',
#   'project human development chicago neighbourhoods'],
#  'NHS': ['national hospice study'],
#  'AHS': ['adolescent health study',
#   'add health sibling',
#   'add health sample',
#   'add health study',
#   'adolescent health survey',
#   'american housing survey',
#   'add health survey',
#   'add health surveys'],
#  'CLHNS': ['cebu longitudinal health nutrition survey'],
#  'CHNS': ['chinese health nutrition survey',
#   'china health nutrition survey',
#   'china health national survey',
#   'china health nutrition surveys'],
#  'ACTIVE': ['advanced cognitive training independent vital elderly'],
#  'CTS': ['community tracking survey',
#   'community tracking studyphysicians',
#   'community tracking studys',
#   'community tracking study'],
#  'CPES': ['collaborative psychiatric epidemiological surveys',
#   'collaborative psychiatric epidemiology studies',
#   'collaborative psychiatric epidemiology survey',
#   'collaborative psychiatric epidemiology surveys'],
#  'NCS': ['national congregations study',
#   'national comorbidity surveyadolescent',
#   'national comorbidity supplement',
#   'national crime survey',
#   'national comorbidity study',
#   'national comorbidity survey'],
#  'CLHLS': ['chinese longitudinal healthy longevity survey',
#   'chinese longitudinal health longevity survey',
#   'chinese longitudinal health longevity study'],
#  'NEISS': ['national electronic injury surveillance systemall',
#   'national electronic injury surveillance system'],
#  'CPSC': ['consumer product safety commission',
#   'consumer product safety commissions'],
#  'DATOS': ['drug abuse treatment outcome study',
#   'drug abuse treatment outcome studies',
#   'drug abuse treatment outcomes study'],
#  'MDICP': ['malawi diffusion ideation change project',
#   'malawi diffusion ideational change project'],
#  'MLSFH': ['malawi longitudinal study families health'],
#  'NSDUH': ['national surveys drug use health',
#   'national survey drug use health'],
#  'LAC': ['latin american caribbean', 'latin america caribbean'],
#  'CILS': ['children immigrants longitudinal survey',
#   'children immigrants longitudinal study'],
#  'CNLSY': ['children national longitudinal survey youth'],
#  'NLSY': ['national longitudinal survey youth'],
#  'NPHS': ['national pregnancy health survey'],
#  'SALSA': ['sacramento area latino study aging'],
#  'NSFG': ['national survey family growth'],
#  'NSAS': ['national survey ambulatory surgery'],
#  'MID': ['militarized interstate dispute'],
#  'CHIP': ['chinese household income project',
#   'china household income project'],
#  'MCD': ['multiple causes death',
#   'multiple cause detail',
#   'multiple causeof death',
#   'multiple cause death'],
#  'MCOD': ['multiple cause ofdeath data'],
#  'CMF': ['cause mortality files', 'compressed mortality file'],
#  'NDI': ['national death index'],
#  'SECCYD': ['study early child care youth development'],
#  'SATSA': ['swedish adoption twin study aging'],
#  'BJBC': ['better jobs better care'],
#  'HOS': ['health outcome survey', 'health outcomes survey'],
#  'MHOS': ['medicare health outcomes survey'],
#  'CES': ['consumer expenditure survey'],
#  'TED': ['treatment episode dataset', 'treatment episode data'],
#  'TEDS': ['treatment episode data set', 'treatment episodes data set'],
#  'ASAPS': ['adolescent substance abuse prevention study'],
#  'CLOC': ['changing lives older couples'],
#  'LSADT': ['longitudinal study aging danish twins'],
#  'NIDA': ['national institute drug abuse'],
#  'SATHCAP': ['sexual acquisition transmission hiv cooperative agreement program'],
#  'SATH': ['sexual acquisition transmission hiv'],
#  'CAP': ['cooperative agreement program'],
#  'CSDD': ['cambridge study delinquent development'],
#  'BJS': ['bureau justice statistics'],
#  'NCRP': ['national corrections reporting program'],
#  'SISFCF': ['survey inmates state federal correctional facilities'],
#  'SISCF': ['survey inmates state correctional facilities'],
#  'SIFCF': ['survey inmates federal correctional facilities'],
#  'NSFEC': ['national survey family economic conditions',
#   'national surveys family economic conditions'],
#  'IHDS': ['indian human development survey', 'india human development survey'],
#  'NVDRS': ['national violent death reporting system'],
#  'TUS': ['tobacco use supplement'],
#  'CDS': ['child development supplement'],
#  'SYRP': ['survey youth residential placement'],
#  'WHO': ['world health organisation',
#   'world health organizations',
#   'world health organization'],
#  'NAMCS': ['namcsnational ambulatory medical care survey',
#   'national ambulatory medical care surveys',
#   'national ambulatory medical care survey',
#   'national ambulatory medical care surveynamcs'],
#  'NHAMCS': ['national hospital ambulatory medical care survery',
#   'national hospital ambulatory medical care survey'],
#  'MLS': ['maternal lifestyle study'],
#  'SEBAS': ['social environment biomarkers aging study'],
#  'CAS': ['college alcohol survey',
#   'college alcohol surveys',
#   'college alcohol studys',
#   'college alcohol study',
#   'chicago area study'],
#  'FFCW': ['fragile families child well', 'fragile families child wellbeing'],
#  'FFCWS': ['fragile families child wellbeing study',
#   'fragile families child well study'],
#  'FFS': ['fragile families study',
#   'fragile families survey',
#   'fragile families sample'],
#  'WFHS': ['work family health study'],
#  'DCRP': ['deaths custody reporting program'],
#  'NPS': ['national prisoner statistics'],
#  'FES': ['family exchanges study'],
#  'RDSL': ['relationship dynamics social life'],
#  'CHIPS': ['chinese household income project series',
#   'chinese household income project surveys',
#   'chinese household income project survey'],
#  'LEMAS': ['law enforcement management administrative statistics'],
#  'NIBRS': ['national incident based reporting system'],
#  'LEOKA': ['law enforcement officers killed assaulted'],
#  'NAS': ['national academy sciences'],
#  'NRC': ['national research council'],
#  'NSFB': ['national survey fertility barriers'],
#  'RISE': ['rehabilitative impairment study elderly'],
#  'CWS': ['contingent worker supplement'],
#  'RWJF': ['robert wood johnson foundations', 'robert wood johnson foundation'],
#  'NHSDA': ['national household survey drug abuse'],
#  'CCS': ['cancer control supplement'],
#  'MCBS': ['medicare current beneficiary survey'],
#  'NHES': ['national household education surveys',
#   'national health examination survey',
#   'national household education survey'],
#  'NCI': ['national cancer institutes'],
#  'NMFS': ['national mortality followback studies',
#   'national mortality followback survey'],
#  'NSSCA': ['national survey self care aging'],
#  'HELP': ['hospitalized elderly longitudinal project'],
#  'SUPPORT': ['study understand prognoses preferences outcomes risks treatments',
#   'study understand prognosis preferences outcomes risks treatments',
#   'study understand prognoses preferences outcomes risks treatment',
#   'study understand prognoses preferences outcomes risks treatmentssupport'],
#  'QES': ['quality employment survey'],
#  'NHSLS': ['national health social life survey'],
#  'SBBS': ['small business benefits survey'],
#  'MHS': ['mental health supplement'],
#  'SHR': ['supplementary homicide reports', 'supplementary homicide report'],
#  'NMIHS': ['national maternal infant health survey'],
#  'RLMS': ['russia longitudinal monitoring survey',
#   'russian longitudinal monitoring survey'],
#  'NSPO': ['national survey physician organizations'],
#  'NSAF': ['national survey americas families'],
#  'ECLS': ['early childhood longitudinal study'],
#  'GIBS': ['gambling impact behavior study'],
#  'NORC': ['national opinion research center'],
#  'HBSC': ['health behavior school children'],
#  'SSATS': ['survey substance abuse treatment services'],
#  'MEPS': ['medical expenditure panel survey'],
#  'NSDE': ['national study daily experiences'],
#  'NNHS': ['national nursing home survey'],
#  'CAG': ['community advisory group'],
#  'ACHS': ['alameda county health study'],
#  'TCHS': ['tecumseh community health study'],
#  'NHMS': ['national health measurement study'],
#  'GSS': ['general social survey', 'general social surveys'],
#  'ATUS': ['american time use survey'],
#  'FSS': ['food security supplement'],
#  'IFLS': ['indonesia family life survey',
#   'indonesian family life survey',
#   'indonesian family life surveys'],
#  'ACS': ['american community survey'],
#  'NTIES': ['national treatment improvement evaluation survey'],
#  'USC': ['university southern california'],
#  'IHDP': ['infant health development program'],
#  'ADAM': ['arrestee drug abuse monitoring'],
#  'CJDATS': ['criminal justice drug abuse treatment studies'],
#  'NDATSS': ['national drug abuse treatment system survey'],
#  'ODATS': ['outpatient drug abuse treatment studies'],
#  'EASS': ['east asian social survey'],
#  'SCS': ['school crime supplement'],
#  'HEGIS': ['higher education general information survey'],
#  'LHD': ['local health departments'],
#  'CPHHD': ['center population health health disparities'],
#  'HRMS': ['health reform monitoring survey'],
#  'RPD': ['research pathways desistance'],
#  'SPPA': ['survey public participation arts'],
#  'IIMMLA': ['immigration intergenerational mobility metropolitan los angeles'],
#  'NELS': ['national education longitudinal study'],
#  'RELATE': ['research early life aging trends effects'],
#  'CMGPD': ['china multi generational panel dataset'],
#  'NSAL': ['national survey american life'],
#  'SAQ': ['self administered questionnaire'],
#  'MACC': ['minnesota adolescent community cohort'],
#  'FHWAR': ['fishing hunting wildlife associated recreation'],
#  'PATH': ['population assessment tobacco health'],
#  'OPII': ['organizational process improvement intervention'],
#  'DATS': ['drug abuse treatment studies'],
#  'STIC': ['services treatment implementation corrections'],
#  'CID': ['citizen involvement democracy', 'citizenship involvement democracy'],
#  'NSA': ['national survey adolescents'],
#  'FAS': ['flint adolescent study'],
#  'WLS': ['wisconsin longitudinal study'],
#  'ICVS': ['international crime victimisation survey'],
#  'CSLLEA': ['census state local law enforcement agencies'],
#  'PRMIHS': ['puerto rican maternal infant health study'],
#  'HAALSI': ['health aging africa longitudinal studies indepth',
#   'health aging africa longitudinal study indepth'],
#  'WTORS': ['wheelchair tiedown occupant restraint system'],
#  'NYPD': ['new york police department'],
#  'SQF': ['stop question frisk'],
#  'SWAN': ['study women across nation'],
#  'SCI': ['spinal cord injury'],
#  'PPCS': ['police public contact survey'],
#  'CZO': ['critical zone observatory'],
#  'BCS': ['british crime survey'],
#  'BRFSS': ['behavioral risk factor surveillance system'],
#  'SII': ['study instructional improvement'],
#  'YPP': ['youth participatory politics'],
#  'CNES': ['cross national election study', 'cross national election studies']}

# %%
# Load the stemmer
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()

def stemExpansion(expansion):
    return " ".join([ps.stem(word) for word in expansion.split()])

# %%
## created the stemmed dictionary
lemAbbDict = {}
for k,expList in abbDict.items():
        lemAbbDict[k] = list(set([stemExpansion(exp) for exp in expList]))

# %%
lemAbbDict
# Out:
# {'SRC': ['survey research center'],
#  'CPS': ['current popul survey', 'current popul studi', 'center polit studi'],
#  'NES': ['nation elect studi'],
#  'SIPP': ['survey incom program particip'],
#  'PSID': ['panel studi incom dynam'],
#  'ANES': ['american nation elect studi'],
#  'HIS': ['health interview survey'],
#  'NHIS': ['nation health interview surveymultipl',
#   'nation health interview survey'],
#  'NCHS': ['nation center health statist'],
#  'FBI': ['feder bureau investig'],
#  'UCR': ['uniform crime report'],
#  'NLS': ['nation longitudin survey'],
#  'NLSOM': ['nation longitudin survey older men'],
#  'MFI': ['monetari financi institut'],
#  'MIR': ['mfi interest rate'],
#  'ITS': ['intern trade servic'],
#  'SITS': ['statist intern trade servic'],
#  'SHS': ['secur hold statist'],
#  'PHF': ['panel household financ'],
#  'FDI': ['foreign direct invest'],
#  'RDSC': ['research data servic centr'],
#  'EPESE': ['establish popul epidemiolog studi elderlyepeseprogram',
#   'establish popul epidemiolog studi elderli'],
#  'HEPESE': ['hispan establish popul epidemiolog studi elderli'],
#  'HRS': ['health retir studi', 'health retir survey', 'health retir surv'],
#  'NLTCS': ['nation long term care survey'],
#  'NLTC': ['nation long term care'],
#  'NHEFS': ['nation health epidemiolog follow studi'],
#  'NEFS': ['nutrit epidemiolog follow studi',
#   'nhane epidemiolog follow survey',
#   'nhane epidemiolog followup survey',
#   'nhane epidemiolog followup studi',
#   'nhane epidemiolog follow studi',
#   'nhane epldemiolog fouownp studi',
#   'nation epidemiolog follow studi',
#   'nutrit examin follow studi'],
#  'NIA': ['nation institut age'],
#  'CDC': ['center diseas control'],
#  'NHDS': ['nation hospit discharg survey',
#   'nch hospit discharg survey',
#   'naional hospit discharg survey'],
#  'ECA': ['epidemiolog catchment area'],
#  'NIMH': ['nation institut mental health'],
#  'ACL': ['american chang live'],
#  'HES': ['health examin surrey', 'health examin survey'],
#  'NMES': ['nation medic expenditur survey'],
#  'NSFH': ['nation survey famili household'],
#  'EVS': ['europeanworld valu survey', 'european valu survey'],
#  'WVS': ['world valu survey'],
#  'DAWN': ['drug abus warn network'],
#  'ALSA': ['australian longitudin studi age'],
#  'PHDCN': ['project human develop chicago neighborhood',
#   'project human develop chicago neighbourhood'],
#  'NHS': ['nation hospic studi'],
#  'AHS': ['american hous survey',
#   'add health sibl',
#   'adolesc health studi',
#   'adolesc health survey',
#   'add health sampl',
#   'add health survey',
#   'add health studi'],
#  'CLHNS': ['cebu longitudin health nutrit survey'],
#  'CHNS': ['china health nutrit survey',
#   'chines health nutrit survey',
#   'china health nation survey'],
#  'ACTIVE': ['advanc cognit train independ vital elderli'],
#  'CTS': ['commun track studi',
#   'commun track survey',
#   'commun track studyphysician'],
#  'CPES': ['collabor psychiatr epidemiolog survey',
#   'collabor psychiatr epidemiolog studi'],
#  'NCS': ['nation comorbid survey',
#   'nation comorbid studi',
#   'nation comorbid surveyadolesc',
#   'nation crime survey',
#   'nation comorbid supplement',
#   'nation congreg studi'],
#  'CLHLS': ['chines longitudin healthi longev survey',
#   'chines longitudin health longev studi',
#   'chines longitudin health longev survey'],
#  'NEISS': ['nation electron injuri surveil system',
#   'nation electron injuri surveil systemal'],
#  'CPSC': ['consum product safeti commiss'],
#  'DATOS': ['drug abus treatment outcom studi'],
#  'MDICP': ['malawi diffus ideat chang project'],
#  'MLSFH': ['malawi longitudin studi famili health'],
#  'NSDUH': ['nation survey drug use health'],
#  'LAC': ['latin american caribbean', 'latin america caribbean'],
#  'CILS': ['children immigr longitudin survey',
#   'children immigr longitudin studi'],
#  'CNLSY': ['children nation longitudin survey youth'],
#  'NLSY': ['nation longitudin survey youth'],
#  'NPHS': ['nation pregnanc health survey'],
#  'SALSA': ['sacramento area latino studi age'],
#  'NSFG': ['nation survey famili growth'],
#  'NSAS': ['nation survey ambulatori surgeri'],
#  'MID': ['militar interst disput'],
#  'CHIP': ['china household incom project', 'chines household incom project'],
#  'MCD': ['multipl causeof death', 'multipl caus death', 'multipl caus detail'],
#  'MCOD': ['multipl caus ofdeath data'],
#  'CMF': ['compress mortal file', 'caus mortal file'],
#  'NDI': ['nation death index'],
#  'SECCYD': ['studi earli child care youth develop'],
#  'SATSA': ['swedish adopt twin studi age'],
#  'BJBC': ['better job better care'],
#  'HOS': ['health outcom survey'],
#  'MHOS': ['medicar health outcom survey'],
#  'CES': ['consum expenditur survey'],
#  'TED': ['treatment episod data', 'treatment episod dataset'],
#  'TEDS': ['treatment episod data set'],
#  'ASAPS': ['adolesc substanc abus prevent studi'],
#  'CLOC': ['chang live older coupl'],
#  'LSADT': ['longitudin studi age danish twin'],
#  'NIDA': ['nation institut drug abus'],
#  'SATHCAP': ['sexual acquisit transmiss hiv cooper agreement program'],
#  'SATH': ['sexual acquisit transmiss hiv'],
#  'CAP': ['cooper agreement program'],
#  'CSDD': ['cambridg studi delinqu develop'],
#  'BJS': ['bureau justic statist'],
#  'NCRP': ['nation correct report program'],
#  'SISFCF': ['survey inmat state feder correct facil'],
#  'SISCF': ['survey inmat state correct facil'],
#  'SIFCF': ['survey inmat feder correct facil'],
#  'NSFEC': ['nation survey famili econom condit'],
#  'IHDS': ['india human develop survey', 'indian human develop survey'],
#  'NVDRS': ['nation violent death report system'],
#  'TUS': ['tobacco use supplement'],
#  'CDS': ['child develop supplement'],
#  'SYRP': ['survey youth residenti placement'],
#  'WHO': ['world health organ', 'world health organis'],
#  'NAMCS': ['namcsnat ambulatori medic care survey',
#   'nation ambulatori medic care survey',
#   'nation ambulatori medic care surveynamc'],
#  'NHAMCS': ['nation hospit ambulatori medic care survey',
#   'nation hospit ambulatori medic care surveri'],
#  'MLS': ['matern lifestyl studi'],
#  'SEBAS': ['social environ biomark age studi'],
#  'CAS': ['colleg alcohol studi',
#   'chicago area studi',
#   'colleg alcohol survey'],
#  'FFCW': ['fragil famili child well', 'fragil famili child wellb'],
#  'FFCWS': ['fragil famili child wellb studi',
#   'fragil famili child well studi'],
#  'FFS': ['fragil famili sampl', 'fragil famili studi', 'fragil famili survey'],
#  'WFHS': ['work famili health studi'],
#  'DCRP': ['death custodi report program'],
#  'NPS': ['nation prison statist'],
#  'FES': ['famili exchang studi'],
#  'RDSL': ['relationship dynam social life'],
#  'CHIPS': ['chines household incom project seri',
#   'chines household incom project survey'],
#  'LEMAS': ['law enforc manag administr statist'],
#  'NIBRS': ['nation incid base report system'],
#  'LEOKA': ['law enforc offic kill assault'],
#  'NAS': ['nation academi scienc'],
#  'NRC': ['nation research council'],
#  'NSFB': ['nation survey fertil barrier'],
#  'RISE': ['rehabilit impair studi elderli'],
#  'CWS': ['conting worker supplement'],
#  'RWJF': ['robert wood johnson foundat'],
#  'NHSDA': ['nation household survey drug abus'],
#  'CCS': ['cancer control supplement'],
#  'MCBS': ['medicar current beneficiari survey'],
#  'NHES': ['nation household educ survey', 'nation health examin survey'],
#  'NCI': ['nation cancer institut'],
#  'NMFS': ['nation mortal followback studi', 'nation mortal followback survey'],
#  'NSSCA': ['nation survey self care age'],
#  'HELP': ['hospit elderli longitudin project'],
#  'SUPPORT': ['studi understand prognos prefer outcom risk treatment',
#   'studi understand prognosi prefer outcom risk treatment',
#   'studi understand prognos prefer outcom risk treatmentssupport'],
#  'QES': ['qualiti employ survey'],
#  'NHSLS': ['nation health social life survey'],
#  'SBBS': ['small busi benefit survey'],
#  'MHS': ['mental health supplement'],
#  'SHR': ['supplementari homicid report'],
#  'NMIHS': ['nation matern infant health survey'],
#  'RLMS': ['russia longitudin monitor survey',
#   'russian longitudin monitor survey'],
#  'NSPO': ['nation survey physician organ'],
#  'NSAF': ['nation survey america famili'],
#  'ECLS': ['earli childhood longitudin studi'],
#  'GIBS': ['gambl impact behavior studi'],
#  'NORC': ['nation opinion research center'],
#  'HBSC': ['health behavior school children'],
#  'SSATS': ['survey substanc abus treatment servic'],
#  'MEPS': ['medic expenditur panel survey'],
#  'NSDE': ['nation studi daili experi'],
#  'NNHS': ['nation nurs home survey'],
#  'CAG': ['commun advisori group'],
#  'ACHS': ['alameda counti health studi'],
#  'TCHS': ['tecumseh commun health studi'],
#  'NHMS': ['nation health measur studi'],
#  'GSS': ['gener social survey'],
#  'ATUS': ['american time use survey'],
#  'FSS': ['food secur supplement'],
#  'IFLS': ['indonesian famili life survey', 'indonesia famili life survey'],
#  'ACS': ['american commun survey'],
#  'NTIES': ['nation treatment improv evalu survey'],
#  'USC': ['univers southern california'],
#  'IHDP': ['infant health develop program'],
#  'ADAM': ['arreste drug abus monitor'],
#  'CJDATS': ['crimin justic drug abus treatment studi'],
#  'NDATSS': ['nation drug abus treatment system survey'],
#  'ODATS': ['outpati drug abus treatment studi'],
#  'EASS': ['east asian social survey'],
#  'SCS': ['school crime supplement'],
#  'HEGIS': ['higher educ gener inform survey'],
#  'LHD': ['local health depart'],
#  'CPHHD': ['center popul health health dispar'],
#  'HRMS': ['health reform monitor survey'],
#  'RPD': ['research pathway desist'],
#  'SPPA': ['survey public particip art'],
#  'IIMMLA': ['immigr intergener mobil metropolitan lo angel'],
#  'NELS': ['nation educ longitudin studi'],
#  'RELATE': ['research earli life age trend effect'],
#  'CMGPD': ['china multi gener panel dataset'],
#  'NSAL': ['nation survey american life'],
#  'SAQ': ['self administ questionnair'],
#  'MACC': ['minnesota adolesc commun cohort'],
#  'FHWAR': ['fish hunt wildlif associ recreat'],
#  'PATH': ['popul assess tobacco health'],
#  'OPII': ['organiz process improv intervent'],
#  'DATS': ['drug abus treatment studi'],
#  'STIC': ['servic treatment implement correct'],
#  'CID': ['citizenship involv democraci', 'citizen involv democraci'],
#  'NSA': ['nation survey adolesc'],
#  'FAS': ['flint adolesc studi'],
#  'WLS': ['wisconsin longitudin studi'],
#  'ICVS': ['intern crime victimis survey'],
#  'CSLLEA': ['censu state local law enforc agenc'],
#  'PRMIHS': ['puerto rican matern infant health studi'],
#  'HAALSI': ['health age africa longitudin studi indepth'],
#  'WTORS': ['wheelchair tiedown occup restraint system'],
#  'NYPD': ['new york polic depart'],
#  'SQF': ['stop question frisk'],
#  'SWAN': ['studi women across nation'],
#  'SCI': ['spinal cord injuri'],
#  'PPCS': ['polic public contact survey'],
#  'CZO': ['critic zone observatori'],
#  'BCS': ['british crime survey'],
#  'BRFSS': ['behavior risk factor surveil system'],
#  'SII': ['studi instruct improv'],
#  'YPP': ['youth participatori polit'],
#  'CNES': ['cross nation elect studi']}

# %% [markdown]
# # Manual Cleaning of the dictionary

# %% [markdown]
# ## Dictionary with stop word removal

# %%
dict2 = {'SIPP': ['survey incom program particip'],
 'PSID': ['panel studi incom dynam'],
 'NCHS': ['nation center health statist'],
 'FBI': ['feder bureau investig'],
 'NLSOM': ['nation longitudin survey older men'],
 'ITS': ['intern trade servic'],
 'SITS': ['statist intern trade servic'],
 'PHF': ['panel household financ'],
 'RDSC': ['research data servic centr'],
 'EPESE': ['establish popul epidemiolog studi elderli'],
 'HEPESE': ['hispan establish popul epidemiolog studi elderli'],
 'HRS': ['health retir survey'],
 'NHEFS': ['nation health epidemiolog follow studi'],
 'NIA': ['nation institut age'],
 'CDC': ['center diseas control'],
 'NIMH': ['nation institut mental health'],
 'NSFH': ['nation survey famili household'],
 'ALSA': ['australian longitudin studi age'],
 'PHDCN': ['project human develop chicago neighborhood'],
 'CLHNS': ['cebu longitudin health nutrit survey'],
 'ACTIVE': ['advanc cognit train independ vital elderli'],
 'MDICP': ['malawi diffus ideat chang project'],
 'MLSFH': ['malawi longitudin studi famili health'],
 'NSDUH': ['nation survey drug use health'],
 'LAC': ['latin america caribbean'],
 'CILS': ['children immigr longitudin survey'],
 'CNLSY': ['children nation longitudin survey youth'],
 'NLSY': ['nation longitudin survey youth'],
 'NPHS': ['nation pregnanc health survey'],
 'SALSA': ['sacramento area latino studi age'],
 'NSFG': ['nation survey famili growth'],
 'NSAS': ['nation survey ambulatori surgeri'],
 'MCD': ['multipl caus death'],
 'SECCYD': ['studi earli child care youth develop'],
 'SATSA': ['swedish adopt twin studi age'],
 'CLOC': ['chang live older coupl'],
 'LSADT': ['longitudin studi age danish twin'],
 'NIDA': ['nation institut drug abus'],
 'SATHCAP': ['sexual acquisit transmiss hiv cooper agreement program'],
 'SATH': ['sexual acquisit transmiss hiv'],
 'CSDD': ['cambridg studi delinqu develop'],
 'BJS': ['bureau justic statist'],
 'SISFCF': ['survey inmat state feder correct facil'],
 'SISCF': ['survey inmat state correct facil'],
 'SIFCF': ['survey inmat feder correct facil'],
 'NSFEC': ['nation survey famili econom condit'],
 'SYRP': ['survey youth residenti placement'],
 'SEBAS': ['social environ biomark age studi'],
 'WFHS': ['work famili health studi'],
 'DCRP': ['death custodi report program'],
 'RDSL': ['relationship dynam social life'],
 'LEMAS': ['law enforc manag administr statist'],
 'NAS': ['nation academi scienc'],
 'NSFB': ['nation survey fertil barrier'],
 'RISE': ['rehabilit impair studi elderli'],
 'NHSDA': ['nation household survey drug abus'],
 'NSSCA': ['nation survey self care age'],
 'SUPPORT': ['studi understand prognos prefer outcom risk treatment'],
 'QES': ['qualiti employ survey'],
 'NHSLS': ['nation health social life survey'],
 'NMIHS': ['nation matern infant health survey'],
 'NSPO': ['nation survey physician organ'],
 'NSAF': ['nation survey america famili'],
 'GIBS': ['gambl impact behavior studi'],
 'HBSC': ['health behavior school children'],
 'SSATS': ['survey substanc abus treatment servic'],
 'NSDE': ['nation studi daili experi'],
 'USC': ['univers southern california'],
 'IHDP': ['infant health develop program'],
 'CPHHD': ['center popul health health dispar'],
 'RPD': ['research pathway desist'],
 'SPPA': ['survey public particip art'],
 'IIMMLA': ['immigr intergener mobil metropolitan lo angel'],
 'RELATE': ['research earli life age trend effect'],
 'NSAL': ['nation survey american life'],
 'FHWAR': ['fish hunt wildlif associ recreat'],
 'PATH': ['popul assess tobacco health'],
 'STIC': ['servic treatment implement correct'],
 'NSA': ['nation survey adolesc'],
 'CSLLEA': ['censu state local law enforc agenc'],
 'PRMIHS': ['puerto rican matern infant health studi'],
 'HAALSI': ['health age africa longitudin studi indepth'],
 'WTORS': ['wheelchair tiedown occup restraint system'],
 'SQF': ['stop question frisk'],
 'SWAN': ['studi women across nation'],
 'SII': ['studi instruct improv'],
 'NSHAP': ['nation social life health and age project']       }

# %% [markdown]
# ## Dict with out stop word removal

# %%
myDict ={'SRC': ['survey research center'],
 'NES': ['nation elect studi'],
 'CPS': ['current popul survey'],
 'MTF': ['monitor the futur'],
 'ANES': ['american nation elect studi'],
 'HIS': ['health interview survey'],
 'NHIS': ['nation health interview survey'],
 'UCR': ['uniform crime report'],
 'NLS': ['nation longitudin survey'],
 'MTFS': ['monitor the futur survey'],
 'NHANES': ['nation health and nutrit examin survey'],
 'MFI': ['monetari financi institut'],
 'MIR': ['mfi interest rate'],
 'SHS': ['secur hold statist'],
 'FDI': ['foreign direct invest'],
 'NLTCS': ['nation long term care survey'],
 'NLTC': ['nation long term care'],
 'NHANESI': ['nation health and nutrit examin survey I'],
 'NEFS': ['nhane epidemiolog followup survey'],
 'HANES': ['health and nutrit examin survey'],
 'NHDS': ['nation hospit discharg survey'],
 'ECA': ['epidemiolog catchment area'],
 'ACL': ['american chang live'],
 'LSOA': ['longitudin studi on age'],
 'SOA': ['studi on age'],
 'HES': ['health examin survey'],
 'NMES': ['nation medic expenditur survey'],
 'HHANES': ['hispan health and nutrit examin survey'],
 'EVS': ['european valu survey'],
 'WVS': ['world valu survey'],
 'DAWN': ['drug abus warn network'],
 'NHS': ['nation hospic studi'],
 'AHS': ['adolesc health survey'],
 'CHNS': ['china health nation survey'],
 'CTS': ['commun track survey'],
 'CPES': ['collabor psychiatr epidemiolog survey'],
 'NCS': ['nation comorbid survey'],
 'CLHLS': ['chines longitudin health longev survey'],
 'NEISS': ['nation electron injuri surveil system'],
 'AIP': ['all injuri program'],
 'CPSC': ['consum product safeti commiss'],
 'DATOS': ['drug abus treatment outcom studi'],
 'MID': ['militar interst disput'],
 'CHIP': ['china household incom project'],
 'MCOD': ['multipl caus of death'],
 'CMF': ['compress mortal file'],
 'NDI': ['nation death index'],
 'CPFOA': ['commun partnership for older adult'],
 'BJBC': ['better job better care'],
 'HOS': ['health outcom survey'],
 'MHOS': ['medicar health outcom survey'],
 'CES': ['consum expenditur survey'],
 'TED': ['treatment episod data'],
 'TEDS': ['treatment episod data set'],
 'ASAPS': ['adolesc substanc abus prevent studi'],
 'CAP': ['cooper agreement program'],
 'NCRP': ['nation correct report program'],
 'IHDS': ['india human develop survey'],
 'NVDRS': ['nation violent death report system'],
 'TUS': ['tobacco use supplement'],
 'CDS': ['child develop supplement'],
 'WHO': ['world health organ'],
 'NAMCS': ['nation ambulatori medic care survey'],
 'NHAMCS': ['nation hospit ambulatori medic care survey'],
 'MLS': ['matern lifestyl studi'],
 'CAS': ['colleg alcohol survey'],
 'FFCW': ['fragil famili child wellb'],
 'FFCWS': ['fragil famili child wellb studi'],
 'FFS': ['fragil famili survey'],
 'NPS': ['nation prison statist'],
 'FES': ['famili exchang studi'],
 'CHIPS': ['chines household incom project survey'],
 'NIBRS': ['nation incid base report system'],
 'LEOKA': ['law enforc offic kill and'],
 'NRC': ['nation research council'],
 'CVAR': ['commun vulner and respons'],
 'CWS': ['conting worker supplement'],
 'RWJF': ['robert wood johnson foundat'],
 'CCS': ['cancer control supplement'],
 'MCBS': ['medicar current beneficiari survey'],
 'NHES': ['nation health examin survey'],
 'NCI': ['nation cancer institut'],
 'NMFS': ['nation mortal followback survey'],
 'HELP': ['hospit elderli longitudin project'],
 'SBBS': ['small busi benefit survey'],
 'MHS': ['mental health supplement'],
 'SHR': ['supplementari homicid report'],
 'RLMS': ['russian longitudin monitor survey'],
 'CIC': ['commun in charg'],
 'ECLS': ['earli childhood longitudin studi'],
 'NORC': ['nation opinion research center'],
 'MEPS': ['medic expenditur panel survey'],
 'NNHS': ['nation nurs home survey'],
 'CAG': ['commun advisori group'],
 'AFL': ['activ for life'],
 'ACHS': ['alameda counti health studi'],
 'TCHS': ['tecumseh commun health studi'],
 'NHMS': ['nation health measur studi'],
 'GSS': ['gener social survey'],
 'ATUS': ['american time use survey'],
 'FSS': ['food secur supplement'],
 'IFLS': ['indonesian famili life survey'],
 'ACS': ['american commun survey'],
 'ASOC': ['and sens of control'],
 'NTIES': ['nation treatment improv evalu survey'],
 'LSOG': ['longitudin studi of gener'],
 'ETV': ['exposur to violenc'],
 'MTO': ['move to opportun'],
 'ADAM': ['arreste drug abus monitor'],
 'AHEAD': ['addict health evalu and diseas'],
 'CJDATS': ['crimin justic drug abus treatment studi'],
 'NDATSS': ['nation drug abus treatment system survey'],
 'ODATS': ['outpati drug abus treatment studi'],
 'EASS': ['east asian social survey'],
 'SCS': ['school crime supplement'],
 'HEGIS': ['higher educ gener inform survey'],
 'LHD': ['local health depart'],
 'HRMS': ['health reform monitor survey'],
 'NELS': ['nation educ longitudin studi'],
 'CMGPD': ['china multi gener panel dataset'],
 'SAQ': ['self administ questionnair'],
 'MACC': ['minnesota adolesc commun cohort'],
 'OPII': ['organiz process improv intervent'],
 'DATS': ['drug abus treatment studi'],
 'CID': ['citizenship involv democraci'],
 'FAS': ['flint adolesc studi'],
 'WLS': ['wisconsin longitudin studi'],
 'ICVS': ['intern crime victimis survey'],
 'BTG': ['bridg the gap'],
 'NYPD': ['new york polic depart'],
 'SCI': ['spinal cord injuri'],
 'PPCS': ['polic public contact survey'],
 'CZO': ['critic zone observatori'],
 'BCS': ['british crime survey'],
 'BRFSS': ['behavior risk factor surveil system'],
 'YPP': ['youth participatori polit'],
 'CNES': ['cross nation elect studi']}

# %%
# Merging the dictionaries
for k,v in dict2.items():
    if k not in myDict:
        myDict[k] = v

# %%
# cheching if any abbreviation has multiple expansions
for k,v in dict2.items():
    if len(v) >1:
        print(k)

# %%
# Saving the dictionary
with open('abbreviations.json', 'w') as fp:
    json.dump(myDict, fp)
